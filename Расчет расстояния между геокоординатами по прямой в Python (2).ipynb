# %% [markdown]
# ## Расчет расстояния между геокоординатами по прямой в Python

# %% [markdown]
# Считаем расстояния между объектами по их координатам. В данном примере будем считать расстояния от населенных пунктов до школ и выбирать ближайшую школу.
#
# Важно: расстояния считаются по прямой, без учета дорог, гор, рек и пр., поэтому дают только общее представление о дальности объектов. Чтобы точно рассчитать дистанцию и время в пути по дорогам, можно воспользоваться API матрицы расстояний Яндекс.Карт (платно, либо можно попробовать попросить бесплатно в исследовательских и научных целях по индивидуальному запросу) или OSRM — Open Sourced Routing Machine (бесплатно)

# %% [markdown]
# ### 1. Скачивание данных

# %% [markdown]
# 1. Данные по населенным пунктам скачиваем на сайте ИНИД (Инфраструктура научно-исследовательских данных) https://www.data-in.ru/data-catalog/datasets/160/
# 2. Данные по школам — парсингом сайта https://schoolotzyv.ru/schools/9-russia/ (данные доступны в формате json по ссылке https://drive.google.com/file/d/12zw_ZroDTfYKSjsUCPZy3GRhTluzmljx/view?usp=sharing) По некоторым регионам на нем есть не все школы. Можно дополнить данными с сайтов https://arhangelsk.fulledu.ru/, https://russiaedu.ru/, набора открытых данных с лицензиями Рособрнадзора (требуется парсинг xml) http://obrnadzor.gov.ru/otkrytoe-pravitelstvo/opendata/7701537808-fbdrl/ и других источников.

# %% [markdown]
# ### 2. Загрузка библиотек

# %%
import pandas as pd # будем работать в pandas
import numpy as np # numpy и sklearn для математических расчетов и использования формул
import sklearn.neighbors
import json # для работы с файлами в формате json

# %% [markdown]
# ### 3. Загрузка и подготовка данных

# %%
# загружаем датасет со школами в pandas

with open('/Users/me/Downloads/schoolotzyv (1).json', 'r') as read_file:
    otzyv = json.load(read_file)

# %%
otzyv = pd.DataFrame(otzyv)
otzyv
# Out:
#          geo_lat    geo_long  \
# 0      54.154966  155.843419
# 1      52.928782  156.573372
# 2      52.670512  156.238983
# 3      52.824094  156.285057
# 4      51.494019  156.501408
# ...          ...         ...
# 50804  55.924598  158.693755
# 50805  56.053578  158.971110
# 50806  54.299330  155.948234
# 50807  55.026700  155.591163
# 50808  55.609792  155.612839
#
#                                                      url  \
# 0      https://schoolotzyv.ru/component/schools/9-rus...
# 1      https://schoolotzyv.ru/component/schools/9-rus...
# 2      https://schoolotzyv.ru/component/schools/9-rus...
# 3      https://schoolotzyv.ru/component/schools/9-rus...
# 4      https://schoolotzyv.ru/component/schools/9-rus...
# ...                                                  ...
# 50804  https://schoolotzyv.ru/component/schools/9-rus...
# 50805  https://schoolotzyv.ru/component/schools/9-rus...
# 50806  https://schoolotzyv.ru/component/schools/9-rus...
# 50807  https://schoolotzyv.ru/component/schools/9-rus...
# 50808  https://schoolotzyv.ru/component/schools/9-rus...
#
#                               text
# 0                Школа с. Устьевое
# 1            Большерецкая школа №5
# 2          Школа №1 п. Октябрьский
# 3         Школа с. Усть-Большерецк
# 4             Школа п. Озерновский
# ...                            ...
# 50804                Школа с. Эссо
# 50805             Школа с. Анавгай
# 50806            Школа с. Соболево
# 50807      Школа п. Крутогоровский
# 50808  Начальная школа п. Ичинский
#
# [50809 rows x 4 columns]

# %%
# нам нужно узнать регионы, для этого выбираем любую ссылку, переходим по ней и смотрим, как в ссылках зашит нужный нам регион

otzyv.loc[1,'url']
# Out:
# 'https://schoolotzyv.ru/component/schools/9-russia/131-kamchatskij/64530-obshheobrazovatelnaya-shkola'

# %%
# для примера возьмем Нижегородскую область (если взять всю Россию, считаться будет долго)
# она в ссылках на школы помечена как "146-nizhegorodskaya"
# выбираем только те строки, которые содержат такую запись
# подробнее о том как фильтровать датафреймы в pandas — в уроке https://istories.media/workshops/2021/03/05/python-biblioteka-pandas-chast-1/


schools_nn = otzyv[otzyv['url'].str.contains('146-nizhegorodskaya')]
len(schools_nn)
# Out:
# 1245

# %%
schools_nn
# Out:
#          geo_lat   geo_long  \
# 7598   55.784521  44.781727
# 7599   55.825548  44.761182
# 7600   55.886998  44.695407
# 7601   55.820749  44.688356
# 7602   55.829173  44.525374
# ...          ...        ...
# 8838   56.181499  44.075750
# 8839   56.288776  44.003723
# 8840   56.530916  43.459353
# 43394  56.263447  44.015293
# 45225  56.363588  43.820008
#
#                                                      url  \
# 7598   https://schoolotzyv.ru/component/schools/9-rus...
# 7599   https://schoolotzyv.ru/component/schools/9-rus...
# 7600   https://schoolotzyv.ru/component/schools/9-rus...
# 7601   https://schoolotzyv.ru/component/schools/9-rus...
# 7602   https://schoolotzyv.ru/component/schools/9-rus...
# ...                                                  ...
# 8838   https://schoolotzyv.ru/component/schools/9-rus...
# 8839   https://schoolotzyv.ru/component/schools/9-rus...
# 8840   https://schoolotzyv.ru/component/schools/9-rus...
# 43394  https://schoolotzyv.ru/component/schools/9-rus...
# 45225  https://schoolotzyv.ru/component/schools/9-rus...
#
#                                                     text
# 7598                            Большемурашкинская школа
# 7599                                   Холязинская школа
# 7600                                    Кишкинская школа
# 7601                                     Советская школа
# 7602                                 Карабатовская школа
# ...                                                  ...
# 8838                  Мореновская санаторно-лесная школа
# 8839             Нижегородская школа-интернат для слепых
# 8840   Нижегородская кадетская школа-интернат им. Мар...
# 43394                         Школа №131 Нижний Новгород
# 45225   Сормовская православная гимназия Нижний Новгород
#
# [1245 rows x 4 columns]

# %%
# поскольку мы выбрали только некоторые строки, индексы датафрейма сбились
# чтобы они опять начинались с нуля, нужно их сбросить методом reset_index

schools_nn = schools_nn.reset_index(drop = True)

# %%
# загружаем датасет с населенными пунктами

places = pd.read_csv('/Users/me/Downloads/places.csv')
places
# Out:
#             id               region                municipality  \
# 0            0    Орловская область                  Болховский
# 1            1      Республика Крым                      Алушта
# 2            2     Липецкая область       Лев-Толстовский район
# 3            3     Тверская область         Селижаровский район
# 4            4      Томская область          Парабельский район
# ...        ...                  ...                         ...
# 155916  155916  Ульяновская область           Вешкаймский район
# 155917  155917    Псковская область            Палкинский район
# 155918  155918    Псковская область             Себежский район
# 155919  155919     Тульская область  рабочий пос. Новогуровский
# 155920  155920   Краснодарский край          Город-курорт Анапа
#
#            settlement   type  population  children latitude_dms longitude_dms  \
# 0          Колонтаева      д           0         0     53.22.07     035.54.36
# 1             Пушкино      с         273         0     44.35.45     034.20.27
# 2            Барятино      с           7         1     53.15.46     039.30.14
# 3              Хилово      д           2         0     56.54.20     033.25.09
# 4           Басмасово      д           6         0     58.38.12     082.02.40
# ...               ...    ...         ...       ...          ...           ...
# 155916       Ребровка      д           0         0     53.59.12     046.48.35
# 155917        Шадрица      д           1         0     57.29.03     028.08.48
# 155918    Овчинниково      д           0         0     56.19.48     028.26.17
# 155919  Новогуровский     рп        3398       305     54.28.03     037.20.19
# 155920  Гостагаевская  ст-ца       12566      2980     45.01.21     037.30.15
#
#         latitude_dd  longitude_dd         oktmo  dadata  rosstat
# 0         53.368611     35.910000  5.460442e+10       0        1
# 1         44.595833     34.340833  3.570300e+10       0        1
# 2         53.262778     39.503889  4.263641e+10       0        1
# 3         56.905556     33.419167  2.865043e+10       0        1
# 4         58.636667     82.044444  6.964444e+10       0        1
# ...             ...           ...           ...     ...      ...
# 155916    53.986667     46.809722  7.360744e+10       0        1
# 155917    57.484167     28.146667  5.863742e+10       0        1
# 155918    56.330000     28.438056  5.865410e+10       0        1
# 155919    54.467500     37.338611  7.070200e+10       1        0
# 155920    45.022500     37.504167  3.703000e+09       1        0
#
# [155921 rows x 14 columns]

# %%
# для примера выбираем только Нижегородскую область и только один район — например, Воскресенский 
# (чтобы точно всё быстро посчиталось на небольшом объеме данных)

places_voskresensk = places[(places['region'] == 'Нижегородская область') & 
                            (places['municipality'] == 'Воскресенский район')]
len(places_voskresensk)
# Out:
# 163

# %%
# опять обновляем индексы, чтобы шли с нуля 

places_voskresensk = places_voskresensk.reset_index(drop = True)

# %% [markdown]
# ### 4. Создание словарей

# %% [markdown]
# Прежде чем считать расстояния, нам понадобится создать два словаря — с населенными пунктами и со школами. Это нужно, чтобы в дальнейшем мы могли сопоставить разные датафреймы по какому-то уникальному параметру, доставать и добавлять нужные нам данные. Это нам пригодится на последних этапах.
#
# Для населенных пунктов таким уникальным параметром будет код ОКТМО (Общероссийского классификатора территорий муниципальных образований)
#
# Перед этим нам нужно убедиться, что:
# 1) Во всех нужных нам столбцахуказан правильный тип данных
#
# 2) Удалить дубликаты в тех столбцах, которые будут уникальным ключом для словаря (для населенных пунктов это поле oktmo, для школ — url, ссылка)

# %%
# смотрим какой тип данный в столбце 'oktmo'

places_voskresensk['oktmo'].dtype
# Out:
# dtype('float64')

# %%
# float, а нам нужны строки, поэтому меняем сначала на integer, а затем на str

# %%
places_voskresensk['oktmo'] = places_voskresensk['oktmo'].astype('int').astype('str')
places_voskresensk['oktmo'].dtype
# Out:
# dtype('O')

# %%
# удаляем дубликты и сбрасываем индексы 

places_voskresensk[places_voskresensk['oktmo'].duplicated()]
# Out:
#          id                 region         municipality settlement type  \
# 94    88013  Нижегородская область  Воскресенский район  Безводное    д
# 107  105267  Нижегородская область  Воскресенский район   Осиновка    д
# 118  116684  Нижегородская область  Воскресенский район    Пузеево    д
# 133  127088  Нижегородская область  Воскресенский район  Богданово    д
# 135  129089  Нижегородская область  Воскресенский район   Калиниха    д
#
#      population  children latitude_dms longitude_dms  latitude_dd  \
# 94           17         0     56.56.48     045.25.17    56.946667
# 107          57         8     56.37.21     045.33.42    56.622500
# 118          34         3     56.49.46     045.14.38    56.829444
# 133          32        10     56.44.03     045.38.21    56.734167
# 135         233        68     56.48.50     045.25.58    56.813889
#
#      longitude_dd         oktmo  dadata  rosstat
# 94      45.421389  2.262245e+10       0        1
# 107     45.561667  2.262242e+10       0        1
# 118     45.243889  2.262240e+10       0        1
# 133     45.639167  2.262241e+10       0        1
# 135     45.432778  2.262215e+10       0        1

# %%
places_voskresensk = places_voskresensk[~places_voskresensk['oktmo'].duplicated()]
places_voskresensk = places_voskresensk.reset_index(drop = True)

# %%
# собираем датафрейм с населенными пунктами в словарь 


places_by_oktmo = {} # пустой словарь 
for i in range(len(places_voskresensk)): # i это индекс, порядковый номер строки
    el = places_voskresensk.loc[i] # записываем в переменную el строку с индексом i 
    places_by_oktmo[el['oktmo']] = el # создаем словарь, где ключом будет код октмо, 
                                    # а значением — соответствующая ему строка датафрейма
len(places_voskresensk)
# Out:
# 158

# %%
# (чтобы посмотреть, что содержится в el, попробуйте вывести на экран в отдельной ячейке places_voskresensk.loc[1] (или другое число))

# %%
places_voskresensk.loc[1]
# Out:
# id                                1902
# region           Нижегородская область
# municipality       Воскресенский район
# settlement                    Докукино
# type                                 с
# population                         237
# children                            40
# latitude_dms                  56.43.39
# longitude_dms                045.41.59
# latitude_dd                    56.7275
# longitude_dd                   45.6997
# oktmo                      2.26224e+10
# dadata                               0
# rosstat                              1
# Name: 1, dtype: object

# %%
places_by_oktmo['22622416166'] # пример того что выдает словарь по ключу - коду октмо
# Out:
# id                                4649
# region           Нижегородская область
# municipality       Воскресенский район
# settlement                   Рассадино
# type                                 д
# population                          11
# children                             2
# latitude_dms                  56.51.18
# longitude_dms                045.05.22
# latitude_dd                     56.855
# longitude_dd                   45.0894
# oktmo                      22622416166
# dadata                               0
# rosstat                              1
# Name: 5, dtype: object

# %%
# переходим к датафрейму со школами 
# сначала меняем тип данных в столбцах с широтой и долгой — были строки, а нужны числа (float)

# %%
schools_nn['geo_lat'].dtype
# Out:
# dtype('O')

# %%
schools_nn['geo_lat'] = schools_nn['geo_lat'].astype('float')
schools_nn['geo_long'] = schools_nn['geo_long'].astype('float')
print(schools_nn['geo_lat'].dtype)
print(schools_nn['geo_long'].dtype)
# Out:
# float64
# float64

# %%
# удаляем дубликаты 
schools_nn[schools_nn['url'].duplicated()]
# Out:
#         geo_lat   geo_long                                                url  \
# 317   55.855785  45.458679  https://schoolotzyv.ru/component/schools/9-rus...
# 405   56.196832  43.855258  https://schoolotzyv.ru/component/schools/9-rus...
# 814   54.916123  43.347369  https://schoolotzyv.ru/component/schools/9-rus...
# 824   54.916123  43.347369  https://schoolotzyv.ru/component/schools/9-rus...
# 850   56.235430  43.415811  https://schoolotzyv.ru/component/schools/9-rus...
# 924   56.335550  44.113685  https://schoolotzyv.ru/component/schools/9-rus...
# 989   56.326388  43.955887  https://schoolotzyv.ru/component/schools/9-rus...
# 996   56.289056  43.851548  https://schoolotzyv.ru/component/schools/9-rus...
# 999   56.312565  43.864385  https://schoolotzyv.ru/component/schools/9-rus...
# 1004  56.302752  43.880537  https://schoolotzyv.ru/component/schools/9-rus...
# 1028  56.280302  43.932639  https://schoolotzyv.ru/component/schools/9-rus...
# 1031  56.289365  43.942520  https://schoolotzyv.ru/component/schools/9-rus...
# 1036  56.315505  43.894631  https://schoolotzyv.ru/component/schools/9-rus...
# 1052  56.328609  44.015032  https://schoolotzyv.ru/component/schools/9-rus...
# 1057  56.326178  44.019892  https://schoolotzyv.ru/component/schools/9-rus...
# 1084  56.306767  43.993284  https://schoolotzyv.ru/component/schools/9-rus...
# 1097  56.285858  44.050363  https://schoolotzyv.ru/component/schools/9-rus...
# 1106  56.368420  43.814546  https://schoolotzyv.ru/component/schools/9-rus...
# 1107  56.364700  43.800416  https://schoolotzyv.ru/component/schools/9-rus...
# 1113  56.362062  43.856776  https://schoolotzyv.ru/component/schools/9-rus...
# 1116  56.379586  43.829764  https://schoolotzyv.ru/component/schools/9-rus...
# 1117  56.386209  43.757521  https://schoolotzyv.ru/component/schools/9-rus...
# 1119  56.343763  43.869272  https://schoolotzyv.ru/component/schools/9-rus...
#
#                                        text
# 317                   Высокоосельская школа
# 405   Школа №88 "Новинская" Нижний Новгород
# 814                          Лицей №3 Саров
# 824                         Лицей №15 Саров
# 850                     Школа №23 Дзержинск
# 924                           Школа №10 Бор
# 989             Гимназия №2 Нижний Новгород
# 996               Школа №75 Нижний Новгород
# 999              Школа №109 Нижний Новгород
# 1004             Школа №167 Нижний Новгород
# 1028             Школа №182 Нижний Новгород
# 1031             Школа №185 Нижний Новгород
# 1036              Школа №64 Нижний Новгород
# 1052            Гимназия №1 Нижний Новгород
# 1057           Гимназия №13 Нижний Новгород
# 1084              Лицей №28 Нижний Новгород
# 1097             Школа №187 Нижний Новгород
# 1106              Школа №79 Нижний Новгород
# 1107              Школа №79 Нижний Новгород
# 1113             Школа №117 Нижний Новгород
# 1116             Школа №156 Нижний Новгород
# 1117             Школа №156 Нижний Новгород
# 1119             Школа №183 Нижний Новгород

# %%
schools_nn = schools_nn[~schools_nn['url'].duplicated()]
schools_nn = schools_nn.reset_index(drop = True)

# %%
# собираем такой же словарь, как с населенными пунктами, только ключом будет url школы

# %%
schools_by_url = {}
for i in range(len(schools_nn)):
    el = schools_nn.loc[i]
    schools_by_url[el['url']] = el
len(schools_by_url)
# Out:
# 1222

# %% [markdown]
# ### 5. Расчет матрицы расстояний

# %% [markdown]
# Переходим к расчету расстояний между каждым населенным пунктом и каждой школой (матрица расстояний). За основу взят туториал Dana Lindquist https://medium.com/@danalindquist/finding-the-distance-between-two-lists-of-geographic-coordinates-9ace7e43bb2f

# %%
# переводим координаты из градусов в радианы, потому что математические формулы обычно требуют 
# значения в радианах, а не в градусах.
# делаем это с помощью библиотеки numpy

schools_nn[['lat_radians_A','long_radians_A']] = (
    np.radians(schools_nn.loc[:,['geo_lat','geo_long']])
)
places_voskresensk[['lat_radians_B','long_radians_B']] = (
    np.radians(places_voskresensk.loc[:,['latitude_dd','longitude_dd']])
)

# %%
# считаем расстояния с помощью формулы из библиотеки scikit-learn
# она вычисляет гаверсинусное расстояние, то есть представляет форму Земли как идеальную сферу (а не геоид, 
# как на самом деле), и за счет этого обеспечивает быстрые вычисления
# если требуется измерение в км, то нужно умножить на 6371, если в милях — на 3959


dist = sklearn.neighbors.DistanceMetric.get_metric('haversine')
dist_matrix = (dist.pairwise
    (schools_nn[['lat_radians_A','long_radians_A']],
     places_voskresensk[['lat_radians_B','long_radians_B']])*6371
)

# %%
# создаем матрицу расстояний — таблицу, в которой индексами будут url школ,
# колонками - октмо населенных пунктов, а в ячейках будет расстояние от каждого населенного пункта до каждой школы

df_dist_matrix = (
    pd.DataFrame(dist_matrix,index=schools_nn['url'], 
                 columns=places_voskresensk['oktmo'])
)

# %%
df_dist_matrix
# Out:
# oktmo                                               22622404111  22622408141  \
# url
# https://schoolotzyv.ru/component/schools/9-russ...   127.780010   119.201251
# https://schoolotzyv.ru/component/schools/9-russ...   123.720058   115.823127
# https://schoolotzyv.ru/component/schools/9-russ...   118.412264   112.124641
# https://schoolotzyv.ru/component/schools/9-russ...   125.547781   118.591238
# https://schoolotzyv.ru/component/schools/9-russ...   128.138590   123.418979
# ...                                                         ...          ...
# https://schoolotzyv.ru/component/schools/9-russ...   109.968831   116.800653
# https://schoolotzyv.ru/component/schools/9-russ...   104.968841   114.928398
# https://schoolotzyv.ru/component/schools/9-russ...   120.463279   138.754476
# https://schoolotzyv.ru/component/schools/9-russ...   106.284631   115.547045
# https://schoolotzyv.ru/component/schools/9-russ...   109.033181   122.118390
#
# oktmo                                               22622440121  22622440151  \
# url
# https://schoolotzyv.ru/component/schools/9-russ...   121.505056   121.558613
# https://schoolotzyv.ru/component/schools/9-russ...   117.546010   117.649458
# https://schoolotzyv.ru/component/schools/9-russ...   112.501179   112.726399
# https://schoolotzyv.ru/component/schools/9-russ...   119.547172   119.728550
# https://schoolotzyv.ru/component/schools/9-russ...   122.566730   122.928302
# ...                                                         ...          ...
# https://schoolotzyv.ru/component/schools/9-russ...   106.948276   108.149707
# https://schoolotzyv.ru/component/schools/9-russ...   102.785402   104.197396
# https://schoolotzyv.ru/component/schools/9-russ...   121.059528   122.986539
# https://schoolotzyv.ru/component/schools/9-russ...   103.909753   105.275720
# https://schoolotzyv.ru/component/schools/9-russ...   107.818924   109.437242
#
# oktmo                                               22622420111  22622416166  \
# url
# https://schoolotzyv.ru/component/schools/9-russ...   138.361254   120.534432
# https://schoolotzyv.ru/component/schools/9-russ...   134.471863   116.243516
# https://schoolotzyv.ru/component/schools/9-russ...   129.565667   110.337659
# https://schoolotzyv.ru/component/schools/9-russ...   136.566682   117.629897
# https://schoolotzyv.ru/component/schools/9-russ...   139.735407   119.245118
# ...                                                         ...          ...
# https://schoolotzyv.ru/component/schools/9-russ...   123.425079    97.338667
# https://schoolotzyv.ru/component/schools/9-russ...   118.640925    91.580269
# https://schoolotzyv.ru/component/schools/9-russ...   133.820130   105.852909
# https://schoolotzyv.ru/component/schools/9-russ...   119.920841    93.051856
# https://schoolotzyv.ru/component/schools/9-russ...   122.773815    94.974386
#
# oktmo                                               22622420181  22622460141  \
# url
# https://schoolotzyv.ru/component/schools/9-russ...   148.722942   132.194424
# https://schoolotzyv.ru/component/schools/9-russ...   144.827854   128.204140
# https://schoolotzyv.ru/component/schools/9-russ...   139.892652   123.062810
# https://schoolotzyv.ru/component/schools/9-russ...   146.906802   130.145235
# https://schoolotzyv.ru/component/schools/9-russ...   150.004291   132.979666
# ...                                                         ...          ...
# https://schoolotzyv.ru/component/schools/9-russ...
# ...                                                         ...          ...
# https://schoolotzyv.ru/component/schools/9-russ...    92.138507   116.737566
# https://schoolotzyv.ru/component/schools/9-russ...    90.886306   111.579893
# https://schoolotzyv.ru/component/schools/9-russ...   117.778936   126.038017
# https://schoolotzyv.ru/component/schools/9-russ...    91.331990   112.937576
# https://schoolotzyv.ru/component/schools/9-russ...    98.952228   115.368898
#
# oktmo                                               22622416106  22622408221  \
# url
# https://schoolotzyv.ru/component/schools/9-russ...   120.449068   122.370188
# https://schoolotzyv.ru/component/schools/9-russ...   116.184689   119.259356
# https://schoolotzyv.ru/component/schools/9-russ...   110.352227   116.124489
# https://schoolotzyv.ru/component/schools/9-russ...   117.628477   122.298962
# https://schoolotzyv.ru/component/schools/9-russ...   119.374763   127.767941
# ...                                                         ...          ...
# https://schoolotzyv.ru/component/schools/9-russ...    98.057401   124.171646
# https://schoolotzyv.ru/component/schools/9-russ...    92.457350   122.939105
# https://schoolotzyv.ru/component/schools/9-russ...   107.163618   147.985108
# https://schoolotzyv.ru/component/schools/9-russ...    93.894249   123.420370
# https://schoolotzyv.ru/component/schools/9-russ...    96.025768   130.639277
#
# oktmo                                               22622416176
# url
# https://schoolotzyv.ru/component/schools/9-russ...   116.026382
# https://schoolotzyv.ru/component/schools/9-russ...   111.681204
# https://schoolotzyv.ru/component/schools/9-russ...   105.629020
# https://schoolotzyv.ru/component/schools/9-russ...   112.948994
# https://schoolotzyv.ru/component/schools/9-russ...   114.319733
# ...                                                         ...
# https://schoolotzyv.ru/component/schools/9-russ...    91.788609
# https://schoolotzyv.ru/component/schools/9-russ...    86.021124
# https://schoolotzyv.ru/component/schools/9-russ...   100.901045
# https://schoolotzyv.ru/component/schools/9-russ...    87.487281
# https://schoolotzyv.ru/component/schools/9-russ...    89.519101
#
# [1222 rows x 158 columns]

# %%
# нам нужно расстояние от населенных пунктов до школ, а не наоборот, поэтому транспонируем таблицу —
# меняем индексы и колонки местами

# %%
df_dist_matrix = df_dist_matrix.T
df_dist_matrix
# Out:
# url          https://schoolotzyv.ru/component/schools/9-russia/146-nizhegorodskaya/72980-bolshemurashkinskaya-shkola  \
# oktmo
# 22622404111                                         127.780010
# 22622408141                                         119.201251
# 22622440121                                         121.505056
# 22622440151                                         121.558613
# 22622420111                                         138.361254
# ...                                                        ...
# 22622456126                                          96.823597
# 22622460136                                         134.277545
# 22622416106                                         120.449068
# 22622408221                                         122.370188
# 22622416176                                         116.026382
#
# url          https://schoolotzyv.ru/component/schools/9-russia/146-nizhegorodskaya/72981-xolyazinskaya-shkola  \
# oktmo
# 22622404111                                         123.720058
# 22622408141                                         115.823127
# 22622440121                                         117.546010
# 22622440151                                         117.649458
# 22622420111                                         134.471863
# ...                                                        ...
# 22622456126                                          93.128736
# 22622460136                                         130.258931
# 22622416106                                         116.184689
# 22622408221                                         119.259356
# 22622416176                                         111.681204
#
# url          https://schoolotzyv.ru/component/schools/9-russia/146-nizhegorodskaya/72982-kishkinskaya-shkola  \
# oktmo
# 22622404111                                         118.412264
# 22622408141                                         112.124641
# 22622440121                                         112.501179
# 22622440151                                         112.726399
# 22622420111                                         129.565667
# ...                                                        ...
# 22622456126                                          88.787344
# 22622460136                                         125.044115
# 22622416106                                         110.352227
# 22622408221                                         116.124489
# 22622416176                                         105.629020
#
# url          https://schoolotzyv.ru/component/schools/9-russia/146-nizhegorodskaya/
://schoolotzyv.ru/component/schools/9-russia/146-nizhegorodskaya/119073-soromovskaya-gimnaziya
# oktmo
# 22622404111                                         109.033181
# 22622408141                                         122.118390
# 22622440121                                         107.818924
# 22622440151                                         109.437242
# 22622420111                                         122.773815
# ...                                                        ...
# 22622456126                                          98.952228
# 22622460136                                         115.368898
# 22622416106                                          96.025768
# 22622408221                                         130.639277
# 22622416176                                          89.519101
#
# [158 rows x 1222 columns]

# %% [markdown]
# ### 6. Выбор ближайшего объекта

# %% [markdown]
# Выбираем ближайшую школу к каждому населенному пункту.

# %%
# дальше мы сравниваем каждое значение в строке с предыдущим, чтобы проверить, больше оно или меньше. Меньшее записываем в переменную

schools_and_min_value_by_oktmo = {} # пустой словарь, где ключом будет код октмо, 
                                    #значениями — минимальное расстояние

columns = df_dist_matrix.columns # список с названиями колонок (url школ)
for current_oktmo in df_dist_matrix.index:
    distances = df_dist_matrix.loc[current_oktmo]
    min_distance = None # нужно для начала отсчета, чтобы было с чем сравнивать первое значение в строке
    min_j = None
    for j in range(len(columns)):
        if min_distance is None or min_distance > distances[j]: # сравниваем каждое значение в строке с 
            # предыдущим, чтобы проверить, больше оно или меньше. Меньшее записываем в переменную
            min_distance = distances[j]
            min_j = j 
    schools_and_min_value_by_oktmo[current_oktmo] = (columns[min_j], min_distance)
# заполняем словарь: ключ — код октмо, значение — url ближайшей школы и расстояние до нее
len(schools_and_min_value_by_oktmo)
# Out:
# 158

# %%
schools_and_min_value_by_oktmo['22622440151'] # пример того, что выдает словарь по коду октмо
# Out:
# ('https://schoolotzyv.ru/component/schools/9-russia/146-nizhegorodskaya/73604-chuxlomskaya-shkola',
#  0.014360770987876591)

# %%
# добавляем колонки с мин расстоянием и url школы в датафрейм places_voskresensk (с населенными пунктами)
# создаем списки с полученными выше url и км, чтобы затем добавить их к датафрейму с населенными пунктами

school_url_column = [] 
min_distance_column = []
for oktmo in places_voskresensk['oktmo']:
    (url, distns) = schools_and_min_value_by_oktmo[oktmo]
    school_url_column.append(url) # берем из созданного выше словаря url ближайшей школы(url) и км до нее (distns),
    # добавляем их в словари в том порядке, в каком соответствующие им коды октмо расположены в датафрейме places_voskresensk
    min_distance_column.append(distns)
places_voskresensk['school_url_column'] = school_url_column # добавляем новую колонку с url ближайших школ
places_voskresensk['min_distance_column'] = min_distance_column # добавляем новую колонку с км до этих школ
len(places_voskresensk)
# Out:
# 158

# %%
places_voskresensk
# Out:
#          id                 region         municipality     settlement type  \
# 0         6  Нижегородская область  Воскресенский район        Апариха    д
# 1      1902  Нижегородская область  Воскресенский район       Докукино    с
# 2      2731  Нижегородская область  Воскресенский район      Капустиха    д
# 3      2867  Нижегородская область  Воскресенский район       Чухломка    д
# 4      4089  Нижегородская область  Воскресенский район  Большие Отары    д
# ..      ...                    ...                  ...            ...  ...
# 153  153214  Нижегородская область  Воскресенский район        Клюкино    д
# 154  153490  Нижегородская область  Воскресенский район        Раскаты    д
# 155  154465  Нижегородская область  Воскресенский район  Александровка    д
# 156  154802  Нижегородская область  Воскресенский район      Успенское    с
# 157  154867  Нижегородская область  Воскресенский район        Шадрино    д
#
#      population  children latitude_dms longitude_dms  latitude_dd  \
# 0             0         0     56.53.40     045.19.08    56.894444
# 1           237        40     56.43.39     045.41.59    56.727500
# 2           215        41     56.49.41     045.21.58    56.828056
# 3           187        50     56.49.20     045.24.06    56.822222
# 4           362        79     56.57.43     045.30.31    56.961944
# ..          ...       ...          ...           ...          ...
# 153          29         2     56.35.22     045.22.43    56.589444
# 154         238        22     56.56.43     045.22.59    56.945278
# 155           0         0     56.51.07     045.06.51    56.851944
# 156           1         0     56.42.32     045.51.24    56.708889
# 157         207        18     56.49.09     045.01.32    56.819167
#
#      longitude_dd        oktmo  dadata  rosstat  lat_radians_B  long_radians_B
# 0       45.318889  22622404111       0        1       0.992995        0.790964
# 1       45.699722  22622408141       0        1       0.990082        0.797611
# 2       45.366111  22622440121       0        1       0.991837        0.791788
# 3       45.401667  22622440151       0        1       0.991735        0.792409
# 4       45.508611  22622420111       0        1       0.994173        0.794275
# ..            ...          ...     ...      ...            ...             ...
# 153     45.378611  22622456126       0        1       0.987672        0.792006
# 154     45.383056  22622460136       0        1       0.993883        0.792084
# 155     45.114167  22622416106       0        1       0.992254        0.787391
# 156     45.856667  22622408221       0        1       0.989757        0.800350
# 157     45.025556  22622416176       0        1       0.991682        0.785844
#
# [158 rows x 16 columns]

# %%
# из словаря со школами достаем названия школ по url и тоже добавляем их к датафрейму places_voskresensk новой колонкой


school_name = []

for url in places_voskresensk['school_url_column']:
    school_name.append(schools_by_url[url]['text'])
places_voskresensk['school_name'] = school_name

# %%
# в конце появились 3 новые колонки — url ближайшей школы, сколько до нее км, название школы

places_voskresensk
# Out:
#          id                 region         municipality     settlement type  \
# 0         6  Нижегородская область  Воскресенский район        Апариха    д
# 1      1902  Нижегородская область  Воскресенский район       Докукино    с
# 2      2731  Нижегородская область  Воскресенский район      Капустиха    д
# 3      2867  Нижегородская область  Воскресенский район       Чухломка    д
# 4      4089  Нижегородская область  Воскресенский район  Большие Отары    д
# ..      ...                    ...                  ...            ...  ...
# 153  153214  Нижегородская область  Воскресенский район        Клюкино    д
# 154  153490  Нижегородская область  Воскресенский район        Раскаты    д
# 155  154465  Нижегородская область  Воскресенский район  Александровка    д
# 156  154802  Нижегородская область  Воскресенский район      Успенское    с
# 157  154867  Нижегородская область  Воскресенский район        Шадрино    д
#
#      population  children latitude_dms longitude_dms  latitude_dd  \
# 0             0         0     56.53.40     045.19.08    56.894444
# 1           237        40     56.43.39     045.41.59    56.727500
# 2           215        41     56.49.41     045.21.58    56.828056
# 3           187        50     56.49.20     045.24.06    56.822222
# 4           362        79     56.57.43     045.30.31    56.961944
# ..          ...       ...          ...           ...          ...
# 153          29         2     56.35.22     045.22.43    56.589444
# 154         238        22     56.56.43     045.22.59    56.945278
# 155           0         0     56.51.07     045.06.51    56.851944
# 156           1         0     56.42.32     045.51.24    56.708889
# 157         207        18     56.49.09     045.01.32    56.819167
#
#      longitude_dd        oktmo  dadata  rosstat  lat_radians_B  \
# 0       45.318889  22622404111       0        1       0.992995
# 1       45.699722  22622408141       0        1       0.990082
# 2       45.366111  22622440121       0        1       0.991837
# 3       45.401667  22622440151       0        1       0.991735
# 4       45.508611  22622420111       0        1       0.994173
# ..            ...          ...     ...      ...            ...
# 153     45.378611  22622456126       0        1       0.987672
# 154     45.383056  22622460136       0        1       0.993883
# 155     45.114167  22622416106       0        1       0.992254
# 156     45.856667  22622408221       0        1       0.989757
# 157     45.025556  22622416176       0        1       0.991682
#
#      long_radians_B                                  school_url_column  \
# 0          0.790964  https://schoolotzyv.ru/component/schools/9-rus...
# 1          0.797611  https://schoolotzyv.ru/component/schools/9-rus...
# 2          0.791788  https://schoolotzyv.ru/component/schools/9-rus...
# 3          0.792409  https://schoolotzyv.ru/component/schools/9-rus...
# 4          0.794275  https://schoolotzyv.ru/component/schools/9-rus...
# ..              ...                                                ...
# 153        0.792006  https://schoolotzyv.ru/component/schools/9-rus...
# 154        0.792084  https://schoolotzyv.ru/component/schools/9-rus...
# 155        0.787391  https://schoolotzyv.ru/component/schools/9-rus...
# 156        0.800350  https://schoolotzyv.ru/component/schools/9-rus...
# 157        0.785844  https://schoolotzyv.ru/component/schools/9-rus...
#
#      min_distance_column           school_name
# 0               3.330156  Благовещенская школа
# 1               0.009381     Докукинская школа
# 2               2.248417      Чухломская школа
# 3               0.014361      Чухломская школа
# 4               0.013753  Большеотарская школа
# ..                   ...                   ...
# 153             4.132106     Нестиарская школа
# 154             0.009641      Раскатская школа
# 155             3.524948    Владимирская школа
# 156             9.567901    Красноярская школа
# 157             0.007929      Шадринская школа
#
# [158 rows x 19 columns]

# %%
# сохраним полученный результат в csv 


places_voskresensk.to_csv('voskresensk_closest_schools.csv')

# %% [markdown]
# ### 7. Анализ данных

# %%
# Дальше можно анализировать данные.
# Например, выбрать 15 наиболе удаленных от школ объектов методов nlarest
# подробнее об nlargest и nsmallest https://istories.media/workshops/2021/03/19/python-biblioteka-pandas-chast-3/

# %%
places_voskresensk.nlargest(15,'min_distance_column')
# Out:
#          id                 region         municipality      settlement type  \
# 41    41506  Нижегородская область  Воскресенский район  Красная Звезда    д
# 22    25057  Нижегородская область  Воскресенский район        Автулиха    д
# 85    83050  Нижегородская область  Воскресенский район        Томилиха    д
# 141  138624  Нижегородская область  Воскресенский район        Бахарево    д
# 6      4922  Нижегородская область  Воскресенский район         Петрово    д
# 19    21738  Нижегородская область  Воскресенский район  Красные Поляны    д
# 156  154802  Нижегородская область  Воскресенский район       Успенское    с
# 62    58690  Нижегородская область  Воскресенский район           Завод    д
# 27    27980  Нижегородская область  Воскресенский район        Шурговаш    с
# 65    60613  Нижегородская область  Воскресенский район      Прудовские    д
# 134  133929  Нижегородская область  Воскресенский район  Малое Содомово    д
# 24    25860  Нижегородская область  Воскресенский район         Марково    д
# 57    53456  Нижегородская область  Воскресенский район        Ладыгино    д
# 18    20401  Нижегородская область  Воскресенский район        Бараново    д
# 81    80366  Нижегородская область  Воскресенский район         Пузеево    д
#
#      population  children latitude_dms longitude_dms  latitude_dd  \
# 41            0         0     56.29.48     045.33.09    56.496667
# 22           10         0     56.37.54     045.27.45    56.631667
# 85            2         0     56.41.42     045.51.14    56.695000
# 141          22         2     56.41.55     045.51.08    56.698611
# 6             0         0     57.03.02     045.33.42    57.050556
# 19            1         0     56.50.53     045.46.25    56.848056
# 156           1         0     56.42.32     045.51.24    56.708889
# 62           15         0     56.37.41     045.25.02    56.628056
# 27          114        12     56.46.25     045.14.10    56.773611
# 65            3         0     57.03.11     045.31.26    57.053056
# 134          56         9     57.02.11     045.36.05    57.036389
# 24           28         0     56.38.17     045.22.54    56.638056
# 57           16         5     56.43.07     045.50.06    56.718611
# 18          191        35     56.48.35     045.14.41    56.809722
# 81            1         0     56.49.46     045.14.38    56.829444
#
#      longitude_dd        oktmo  dadata  rosstat  lat_radians_B  \
# 41      45.552500  22622432126       0        1       0.986053
# 22      45.462500  22622456106       0        1       0.988409
# 85      45.853889  22622408206       0        1       0.989514
# 141     45.852222  22622408111       0        1       0.989577
# 6       45.561667  22622420181       0        1       0.995720
# 19      45.773611  22622424141       0        1       0.992186
# 156     45.856667  22622408221       0        1       0.989757
# 62      45.417222  22622456116       0        1       0.988346
# 27      45.236111  22622416186       1        0       0.990886
# 65      45.523889  22622420186       0        1       0.995764
# 134     45.601389  22622420161       0        1       0.995473
# 24      45.381667  22622456131       0        1       0.988521
# 57      45.835000  22622408176       0        1       0.989927
# 18      45.244722  22622416116       0        1       0.991517
# 81      45.243889  22622404176       0        1       0.991861
#
#      long_radians_B                                  school_url_column  \
# 41         0.795041  https://schoolotzyv.ru/component/schools/9-rus...
# 22         0.793470  https://schoolotzyv.ru/component/schools/9-rus...
# 85         0.800301  https://schoolotzyv.ru/component/schools/9-rus...
# 141        0.800272  https://schoolotzyv.ru/component/schools/9-rus...
# 6          0.795201  https://schoolotzyv.ru/component/schools/9-rus...
# 19         0.798900  https://schoolotzyv.ru/component/schools/9-rus...
# 156        0.800350  https://schoolotzyv.ru/component/schools/9-rus...
# 62         0.792680  https://schoolotzyv.ru/component/schools/9-rus...
# 27         0.789519  https://schoolotzyv.ru/component/schools/9-rus...
# 65         0.794542  https://schoolotzyv.ru/component/schools/9-rus...
# 134        0.795894  https://schoolotzyv.ru/component/schools/9-rus...
# 24         0.792060  https://schoolotzyv.ru/component/schools/9-rus...
# 57         0.799972  https://schoolotzyv.ru/component/schools/9-rus...
# 18         0.789669  https://schoolotzyv.ru/component/schools/9-rus...
# 81         0.789655  https://schoolotzyv.ru/component/schools/9-rus...
#
#      min_distance_column           school_name
# 41             11.260120      Егоровская школа
# 22             10.768442      Егоровская школа
# 85             10.087465     Докукинская школа
# 141             9.853790     Докукинская школа
# 6               9.822884  Староустинская школа
# 19              9.708871    Красноярская школа
# 156             9.567901    Красноярская школа
# 62              8.986548     Нестиарская школа
# 27              8.894897    Владимирская школа
# 65              8.605541  Староустинская школа
# 134             8.483822   Воздвиженская школа
# 24              8.310078       Елдежская школа
# 57              7.859978    Красноярская школа
# 18              7.832342    Владимирская школа
# 81              7.757832    Владимирская школа

# %%
# или посчитать, сколько детей в Воскресенском районе Нижегородской обл. живут дальше 5 км от школы

km5 = places_voskresensk[places_voskresensk['min_distance_column'] > 5]
print(places_voskresensk['children'].sum()) # всего детей
print(km5['children'].sum()) # живут дальше 5 км
# Out:
# 3385
# 269

# %%
# или среднее расстояние от населенного пункта до школы 

places_voskresensk['min_distance_column'].mean()
# Out:
# 3.91580963122014

# %% [markdown]
# Готово, спасибо, что дошли до конца!
