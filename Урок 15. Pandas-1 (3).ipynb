# %%
import pandas as pd # загрузка библиотеки Pandas

# %%
dict_city = {"City" : ["Moscow", "Saint-Petersburg", "Novosibirsk"], 
            "Population" : [12678079,   5398064,  1625631]}

df = pd.DataFrame(dict_city) # создание датафрейма из словаря
df
# Out:
#                City  Population
# 0            Moscow    12678079
# 1  Saint-Petersburg     5398064
# 2       Novosibirsk     1625631

# %%
df.to_excel("cities.xlsx") # сохранение датафрейма на компьютер в формате xlsx

# %%
lists_city = [["Moscow", "Saint-Petersburg", "Novosibirsk"], 
[12678079,   5398064,  1625631]]

pd.DataFrame(lists_city) # создание датафрейма из списка списков
# Out:
#           0                 1            2
# 0    Moscow  Saint-Petersburg  Novosibirsk
# 1  12678079           5398064      1625631

# %%
pd.DataFrame(lists_city).T # транспонирование (меням столбцы и строки местами)
# Out:
#                   0         1
# 0            Moscow  12678079
# 1  Saint-Petersburg   5398064
# 2       Novosibirsk   1625631

# %%
df = pd.read_csv("/Users/sherlock/Downloads/IHME-GBD_2019_DATA-ff08d9bc-1/IHME-GBD_2019_DATA-ff08d9bc-1.csv", encoding = "utf-8") 

# создание датафрейма из файла 
# в кавычках нужно прописать путь к файлу на своем компьютере
# его можно скачать по ссылке https://drive.google.com/file/d/16fM_JEC5GAkYEDaDgzROrBm8loi9RZRZ/view 
# в файле данные о смертности людей от разных причин по 204 странам с 2000 по 2019 гг с сайта 
# http://ghdx.healthdata.org/gbd-results-tool

# %%
df.head() # первые 5 строк датафрейма
# Out:
#   measure location     sex       age                           cause metric  \
# 0  Deaths    Samoa    Male  All Ages    Chronic respiratory diseases   Rate
# 1  Deaths    Samoa  Female  All Ages    Chronic respiratory diseases   Rate
# 2  Deaths    Samoa    Both  All Ages    Chronic respiratory diseases   Rate
# 3  Deaths    Samoa    Male  All Ages  Skin and subcutaneous diseases   Rate
# 4  Deaths    Samoa  Female  All Ages  Skin and subcutaneous diseases   Rate
#
#    year        val      upper      lower
# 0  2000  64.470214  81.808307  53.476793
# 1  2000  55.234399  77.883497  39.978647
# 2  2000  60.039961  76.013089  49.941986
# 3  2000   2.246741   3.467454   1.438979
# 4  2000   1.368385   1.945448   0.866099

# %%
df.head(8) # первые 15 строк датафрейма
# Out:
#   measure location     sex       age                           cause metric  \
# 0  Deaths    Samoa    Male  All Ages    Chronic respiratory diseases   Rate
# 1  Deaths    Samoa  Female  All Ages    Chronic respiratory diseases   Rate
# 2  Deaths    Samoa    Both  All Ages    Chronic respiratory diseases   Rate
# 3  Deaths    Samoa    Male  All Ages  Skin and subcutaneous diseases   Rate
# 4  Deaths    Samoa  Female  All Ages  Skin and subcutaneous diseases   Rate
# 5  Deaths    Samoa    Both  All Ages  Skin and subcutaneous diseases   Rate
# 6  Deaths    Samoa    Male  All Ages              Transport injuries   Rate
# 7  Deaths    Samoa  Female  All Ages              Transport injuries   Rate
#
#    year        val      upper      lower
# 0  2000  64.470214  81.808307  53.476793
# 1  2000  55.234399  77.883497  39.978647
# 2  2000  60.039961  76.013089  49.941986
# 3  2000   2.246741   3.467454   1.438979
# 4  2000   1.368385   1.945448   0.866099
# 5  2000   1.825409   2.569260   1.259226
# 6  2000  25.920294  36.084587  18.130636
# 7  2000  10.099048  13.447738   7.330908

# %%
df.tail() # последние 5 строк датафрейма
# Out:
#        measure location     sex       age  \
# 257035  Deaths  Comoros  Female  All Ages
# 257036  Deaths  Comoros    Both  All Ages
# 257037  Deaths  Comoros    Male  All Ages
# 257038  Deaths  Comoros  Female  All Ages
# 257039  Deaths  Comoros    Both  All Ages
#
#                                           cause metric  year        val  \
# 257035  Neglected tropical diseases and malaria   Rate  2004  53.727176
# 257036  Neglected tropical diseases and malaria   Rate  2004  55.473969
# 257037             Chronic respiratory diseases   Rate  2004  26.083547
# 257038             Chronic respiratory diseases   Rate  2004  19.658170
# 257039             Chronic respiratory diseases   Rate  2004  22.849508
#
#             upper      lower
# 257035  92.205694  24.130322
# 257036  96.573472  24.780106
# 257037  32.912324  18.654426
# 257038  25.456633  14.278054
# 257039  27.877194  17.872866

# %%
df.info() # информация о датафрейме
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 257040 entries, 0 to 257039
# Data columns (total 10 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   measure   257040 non-null  object
#  1   location  257040 non-null  object
#  2   sex       257040 non-null  object
#  3   age       257040 non-null  object
#  4   cause     257040 non-null  object
#  5   metric    257040 non-null  object
#  6   year      257040 non-null  int64
#  7   val       257040 non-null  float64
#  8   upper     257040 non-null  float64
#  9   lower     257040 non-null  float64
# dtypes: float64(3), int64(1), object(6)
# memory usage: 19.6+ MB

# %%
df.shape # показывает, сколько в датафрейме строк и столбцов
# Out:
# (257040, 10)

# %%
df.describe() 
# статистическая информация по столбцам (уникальные значения, среднее, стандартное отклонение, минимальное, квартили, максимальное)
# Out:
#                 year            val          upper          lower
# count  257040.000000  257040.000000  257040.000000  257040.000000
# mean     2009.500000      38.800590      47.928737      31.471947
# std         5.766293      78.404349      90.084317      68.696407
# min      2000.000000       0.000007       0.000010       0.000004
# 25%      2004.750000       1.886851       2.501180       1.316783
# 50%      2009.500000      14.271807      18.665022      10.660142
# 75%      2014.250000      38.132807      49.665292      28.921071
# max      2019.000000    2754.279032    3029.881582    2511.135907

# %%
df.describe(include = 'all') # статистика включает не только числовые столбцы, но и строки 
# (unique - сколько уникальных значений, top - какое самое популярное значение, freq - как часто встречается самое популярное)
# Out:
#        measure location     sex       age  \
# count   257040   257040  257040    257040
# unique       1      204       3         1
# top     Deaths  Jamaica    Male  All Ages
# freq    257040     1260   85680    257040
# mean       NaN      NaN     NaN       NaN
# std        NaN      NaN     NaN       NaN
# min        NaN      NaN     NaN       NaN
# 25%        NaN      NaN     NaN       NaN
# 50%        NaN      NaN     NaN       NaN
# 75%        NaN      NaN     NaN       NaN
# max        NaN      NaN     NaN       NaN
#
#                                           cause  metric           year  \
# count                                    257040  257040  257040.000000
# unique                                       21       1            NaN
# top     Respiratory infections and tuberculosis    Rate            NaN
# freq                                      12240  257040            NaN
# mean                                        NaN     NaN    2009.500000
# std                                         NaN     NaN       5.766293
# min                                         NaN     NaN    2000.000000
# 25%                                         NaN     NaN    2004.750000
# 50%                                         NaN     NaN    2009.500000
# 75%                                         NaN     NaN    2014.250000
# max                                         NaN     NaN    2019.000000
#
#                   val          upper          lower
# count   257040.000000  257040.000000  257040.000000
# unique            NaN            NaN            NaN
# top               NaN            NaN            NaN
# freq              NaN            NaN            NaN
# mean        38.800590      47.928737      31.471947
# std         78.404349      90.084317      68.696407
# min          0.000007       0.000010       0.000004
# 25%          1.886851       2.501180       1.316783
# 50%         14.271807      18.665022      10.660142
# 75%         38.132807      49.665292      28.921071
# max       2754.279032    3029.881582    2511.135907

# %%
df.dropna(inplace=True) # удаление пустых значений (missing values, NA)

# %%
df["measure"] # выбор столбца, способ 1
# Out:
# 0         Deaths
# 1         Deaths
# 2         Deaths
# 3         Deaths
# 4         Deaths
#            ...
# 257035    Deaths
# 257036    Deaths
# 257037    Deaths
# 257038    Deaths
# 257039    Deaths
# Name: measure, Length: 257040, dtype: object

# %%
df.measure # выбор столбца, способ 2
# Out:
# 0         Deaths
# 1         Deaths
# 2         Deaths
# 3         Deaths
# 4         Deaths
#            ...
# 257035    Deaths
# 257036    Deaths
# 257037    Deaths
# 257038    Deaths
# 257039    Deaths
# Name: measure, Length: 257040, dtype: object

# %%
df[["location","sex","year"]] # выбор сразу нескольких столбцов
# Out:
#        location     sex  year
# 0         Samoa    Male  2000
# 1         Samoa  Female  2000
# 2         Samoa    Both  2000
# 3         Samoa    Male  2000
# 4         Samoa  Female  2000
# ...         ...     ...   ...
# 257035  Comoros  Female  2004
# 257036  Comoros    Both  2004
# 257037  Comoros    Male  2004
# 257038  Comoros  Female  2004
# 257039  Comoros    Both  2004
#
# [257040 rows x 3 columns]

# %%
df.loc[:, "location":"val"] # выбираем все строки, а столбцы от "location" до "val"
# Out:
#        location     sex       age                                    cause  \
# 0         Samoa    Male  All Ages             Chronic respiratory diseases
# 1         Samoa  Female  All Ages             Chronic respiratory diseases
# 2         Samoa    Both  All Ages             Chronic respiratory diseases
# 3         Samoa    Male  All Ages           Skin and subcutaneous diseases
# 4         Samoa  Female  All Ages           Skin and subcutaneous diseases
# ...         ...     ...       ...                                      ...
# 257035  Comoros  Female  All Ages  Neglected tropical diseases and malaria
# 257036  Comoros    Both  All Ages  Neglected tropical diseases and malaria
# 257037  Comoros    Male  All Ages             Chronic respiratory diseases
# 257038  Comoros  Female  All Ages             Chronic respiratory diseases
# 257039  Comoros    Both  All Ages             Chronic respiratory diseases
#
#        metric  year        val
# 0        Rate  2000  64.470214
# 1        Rate  2000  55.234399
# 2        Rate  2000  60.039961
# 3        Rate  2000   2.246741
# 4        Rate  2000   1.368385
# ...       ...   ...        ...
# 257035   Rate  2004  53.727176
# 257036   Rate  2004  55.473969
# 257037   Rate  2004  26.083547
# 257038   Rate  2004  19.658170
# 257039   Rate  2004  22.849508
#
# [257040 rows x 7 columns]

# %%
df.loc[100:110, "location":"val"] 
# выбираем строки от 100 до 110 (правый край, то есть число 110, в методе iloc включается), столбцы от "location" до "val"
# Out:
#                                   location     sex       age  \
# 100                              Indonesia  Female  All Ages
# 101                              Indonesia    Both  All Ages
# 102                             Azerbaijan    Male  All Ages
# 103                             Azerbaijan  Female  All Ages
# 104                             Azerbaijan    Both  All Ages
# 105  Democratic People's Republic of Korea    Male  All Ages
# 106  Democratic People's Republic of Korea  Female  All Ages
# 107  Democratic People's Republic of Korea    Both  All Ages
# 108                                  China    Male  All Ages
# 109                                  China  Female  All Ages
# 110                                  China    Both  All Ages
#
#                                cause metric  year         val
# 100  Other non-communicable diseases   Rate  2000   15.723363
# 101  Other non-communicable diseases   Rate  2000   17.865424
# 102          Cardiovascular diseases   Rate  2000  359.553595
# 103          Cardiovascular diseases   Rate  2000  362.391800
# 104          Cardiovascular diseases   Rate  2000  361.001364
# 105           Unintentional injuries   Rate  2000   37.650129
# 106           Unintentional injuries   Rate  2000   17.622944
# 107           Unintentional injuries   Rate  2000   27.227035
# 108                 Mental disorders   Rate  2000    0.000133
# 109                 Mental disorders   Rate  2000    0.003382
# 110                 Mental disorders   Rate  2000    0.001707

# %%
df.iloc[100:110, 0:3] 
# выбираем строки от 100 до 109 (правый край, то есть число 110, в методе iloc не включается), столбцы от 0 до 3
# Out:
#     measure                               location     sex
# 100  Deaths                              Indonesia  Female
# 101  Deaths                              Indonesia    Both
# 102  Deaths                             Azerbaijan    Male
# 103  Deaths                             Azerbaijan  Female
# 104  Deaths                             Azerbaijan    Both
# 105  Deaths  Democratic People's Republic of Korea    Male
# 106  Deaths  Democratic People's Republic of Korea  Female
# 107  Deaths  Democratic People's Republic of Korea    Both
# 108  Deaths                                  China    Male
# 109  Deaths                                  China  Female

# %%
df[df["sex"] == "Both"] # выбираем по условию только те строки в столбце "sex", где указаны оба пола ("Both")
# Out:
#        measure         location   sex       age  \
# 2       Deaths            Samoa  Both  All Ages
# 5       Deaths            Samoa  Both  All Ages
# 8       Deaths            Samoa  Both  All Ages
# 11      Deaths            Samoa  Both  All Ages
# 14      Deaths  Solomon Islands  Both  All Ages
# ...        ...              ...   ...       ...
# 257027  Deaths          Burundi  Both  All Ages
# 257030  Deaths          Burundi  Both  All Ages
# 257033  Deaths          Burundi  Both  All Ages
# 257036  Deaths          Comoros  Both  All Ages
# 257039  Deaths          Comoros  Both  All Ages
#
#                                           cause metric  year         val  \
# 2                  Chronic respiratory diseases   Rate  2000   60.039961
# 5                Skin and subcutaneous diseases   Rate  2000    1.825409
# 8                            Transport injuries   Rate  2000   18.331128
# 11                       Unintentional injuries   Rate  2000   20.717772
# 14                    Musculoskeletal disorders   Rate  2000    0.618564
# ...                                         ...    ...   ...         ...
# 257027                         Mental disorders   Rate  2004    0.000541
# 257030     Self-harm and interpersonal violence   Rate  2004  189.760046
# 257033                 Nutritional deficiencies   Rate  2004   47.554185
# 257036  Neglected tropical diseases and malaria   Rate  2004   55.473969
# 257039             Chronic respiratory diseases   Rate  2004   22.849508
#
#              upper       lower
# 2        76.013089   49.941986
# 5         2.569260    1.259226
# 8        25.000813   13.148053
# 11       27.807698   15.596213
# 14        0.854977    0.386121
# ...            ...         ...
# 257027    0.002736    0.000105
# 257030  208.823162  173.350895
# 257033   78.460927   26.723560
# 257036   96.573472   24.780106
# 257039   27.877194   17.872866
#
# [85680 rows x 10 columns]

# %%
df[(df["sex"] == "Both") & (df["cause"] == "Cardiovascular diseases") & (df["year"] == 2019)] # несколько условий сразу
# Out:
#        measure                               location   sex       age  \
# 197037  Deaths                              Sri Lanka  Both  All Ages
# 197268  Deaths                                Armenia  Both  All Ages
# 197298  Deaths                               Viet Nam  Both  All Ages
# 197433  Deaths  Democratic People's Republic of Korea  Both  All Ages
# 197508  Deaths                             Kazakhstan  Both  All Ages
# ...        ...                                    ...   ...       ...
# 235491  Deaths                                  Egypt  Both  All Ages
# 235629  Deaths                                  Congo  Both  All Ages
# 235686  Deaths                                Morocco  Both  All Ages
# 235950  Deaths                                Tunisia  Both  All Ages
# 236175  Deaths                                  Qatar  Both  All Ages
#
#                           cause metric  year         val       upper  \
# 197037  Cardiovascular diseases   Rate  2019  213.123244  271.193595
# 197268  Cardiovascular diseases   Rate  2019  447.304269  515.804063
# 197298  Cardiovascular diseases   Rate  2019  249.199874  289.447813
# 197433  Cardiovascular diseases   Rate  2019  391.058759  452.857961
# 197508  Cardiovascular diseases   Rate  2019  355.541765  399.325605
# ...                         ...    ...   ...         ...         ...
# 235491  Cardiovascular diseases   Rate  2019  266.350999  332.353780
# 235629  Cardiovascular diseases   Rate  2019  134.762018  168.489114
# 235686  Cardiovascular diseases   Rate  2019  325.526242  372.812226
# 235950  Cardiovascular diseases   Rate  2019  302.524818  381.458389
# 236175  Cardiovascular diseases   Rate  2019   39.137849   50.379816
#
#              lower
# 197037  160.527408
# 197268  382.174004
# 197298  209.903244
# 197433  337.013789
# 197508  314.636207
# ...            ...
# 235491  206.500784
# 235629  108.440606
# 235686  263.919650
# 235950  232.286982
# 236175   29.839026
#
# [204 rows x 10 columns]

# %%
df[(df["sex"] == "Both") & (df["cause"] == "Cardiovascular diseases") & (df["year"] == 2019) & (df["val"] > 600)]
# Out:
#        measure             location   sex       age                    cause  \
# 199944  Deaths      North Macedonia  Both  All Ages  Cardiovascular diseases
# 201828  Deaths               Latvia  Both  All Ages  Cardiovascular diseases
# 203892  Deaths   Russian Federation  Both  All Ages  Cardiovascular diseases
# 205248  Deaths              Hungary  Both  All Ages  Cardiovascular diseases
# 207636  Deaths              Ukraine  Both  All Ages  Cardiovascular diseases
# 220377  Deaths              Georgia  Both  All Ages  Cardiovascular diseases
# 223428  Deaths              Romania  Both  All Ages  Cardiovascular diseases
# 223692  Deaths              Estonia  Both  All Ages  Cardiovascular diseases
# 224058  Deaths  Republic of Moldova  Both  All Ages  Cardiovascular diseases
# 224319  Deaths             Bulgaria  Both  All Ages  Cardiovascular diseases
# 230433  Deaths               Serbia  Both  All Ages  Cardiovascular diseases
# 230826  Deaths           Montenegro  Both  All Ages  Cardiovascular diseases
# 231075  Deaths            Lithuania  Both  All Ages  Cardiovascular diseases
# 232800  Deaths              Belarus  Both  All Ages  Cardiovascular diseases
#
#        metric  year          val        upper       lower
# 199944   Rate  2019   651.388575   775.113232  542.852474
# 201828   Rate  2019   823.834965   961.198221  705.494296
# 203892   Rate  2019   684.943411   768.021861  599.861565
# 205248   Rate  2019   638.984813   746.066543  540.141611
# 207636   Rate  2019  1020.326176  1166.207717  890.091470
# 220377   Rate  2019   810.680929   919.323450  696.025755
# 223428   Rate  2019   781.963318   912.699304  666.684367
# 223692   Rate  2019   624.897478   759.074576  503.262686
# 224058   Rate  2019   635.480079   709.063913  565.538636
# 224319   Rate  2019  1140.933052  1349.387220  960.194209
# 230433   Rate  2019   729.051353   853.947585  617.279051
# 230826   Rate  2019   635.545945   728.726560  548.315607
# 231075   Rate  2019   762.327387   895.667660  635.595129
# 232800   Rate  2019   792.975384   977.913501  654.436226

# %%
cardio = df[(df["sex"] == "Both")&(df["cause"] == "Cardiovascular diseases") & (df["year"] == 2019) & (df["val"] > 600)]

# %%
cardio.sort_values(by = ["val"], ascending=False, inplace=False, na_position='last', ignore_index=False)
# сортируем датафрейм по столбцу "val", ascending означает по возрастанию, ascending = False - по убыванию
# Out:
#        measure             location   sex       age                    cause  \
# 224319  Deaths             Bulgaria  Both  All Ages  Cardiovascular diseases
# 207636  Deaths              Ukraine  Both  All Ages  Cardiovascular diseases
# 201828  Deaths               Latvia  Both  All Ages  Cardiovascular diseases
# 220377  Deaths              Georgia  Both  All Ages  Cardiovascular diseases
# 232800  Deaths              Belarus  Both  All Ages  Cardiovascular diseases
# 223428  Deaths              Romania  Both  All Ages  Cardiovascular diseases
# 231075  Deaths            Lithuania  Both  All Ages  Cardiovascular diseases
# 230433  Deaths               Serbia  Both  All Ages  Cardiovascular diseases
# 203892  Deaths   Russian Federation  Both  All Ages  Cardiovascular diseases
# 199944  Deaths      North Macedonia  Both  All Ages  Cardiovascular diseases
# 205248  Deaths              Hungary  Both  All Ages  Cardiovascular diseases
# 230826  Deaths           Montenegro  Both  All Ages  Cardiovascular diseases
# 224058  Deaths  Republic of Moldova  Both  All Ages  Cardiovascular diseases
# 223692  Deaths              Estonia  Both  All Ages  Cardiovascular diseases
#
#        metric  year          val        upper       lower
# 224319   Rate  2019  1140.933052  1349.387220  960.194209
# 207636   Rate  2019  1020.326176  1166.207717  890.091470
# 201828   Rate  2019   823.834965   961.198221  705.494296
# 220377   Rate  2019   810.680929   919.323450  696.025755
# 232800   Rate  2019   792.975384   977.913501  654.436226
# 223428   Rate  2019   781.963318   912.699304  666.684367
# 231075   Rate  2019   762.327387   895.667660  635.595129
# 230433   Rate  2019   729.051353   853.947585  617.279051
# 203892   Rate  2019   684.943411   768.021861  599.861565
# 199944   Rate  2019   651.388575   775.113232  542.852474
# 205248   Rate  2019   638.984813   746.066543  540.141611
# 230826   Rate  2019   635.545945   728.726560  548.315607
# 224058   Rate  2019   635.480079   709.063913  565.538636
# 223692   Rate  2019   624.897478   759.074576  503.262686

# %%
df[(df["location"] == "Russia") | (df["location"] == "Russian Federation")] 
# ищет строки, где либо Russia, либо Russian Federation (соблюдается одно из условий)
# Out:
#        measure            location     sex       age  \
# 285     Deaths  Russian Federation    Male  All Ages
# 286     Deaths  Russian Federation  Female  All Ages
# 287     Deaths  Russian Federation    Both  All Ages
# 312     Deaths  Russian Federation    Male  All Ages
# 313     Deaths  Russian Federation  Female  All Ages
# ...        ...                 ...     ...       ...
# 250424  Deaths  Russian Federation  Female  All Ages
# 250425  Deaths  Russian Federation    Both  All Ages
# 250426  Deaths  Russian Federation    Male  All Ages
# 250427  Deaths  Russian Federation  Female  All Ages
# 250428  Deaths  Russian Federation    Both  All Ages
#
#                                           cause metric  year        val  \
# 285     Neglected tropical diseases and malaria   Rate  2000   0.154956
# 286     Neglected tropical diseases and malaria   Rate  2000   0.075035
# 287     Neglected tropical diseases and malaria   Rate  2000   0.112384
# 312                          Digestive diseases   Rate  2000  59.448209
# 313                          Digestive diseases   Rate  2000  36.099041
# ...                                         ...    ...   ...        ...
# 250424                Other infectious diseases   Rate  2007   1.962272
# 250425                Other infectious diseases   Rate  2007   2.624491
# 250426          Maternal and neonatal disorders   Rate  2007   5.757783
# 250427          Maternal and neonatal disorders   Rate  2007   4.041021
# 250428          Maternal and neonatal disorders   Rate  2007   4.838192
#
#             upper      lower
# 285      0.213816   0.084323
# 286      0.106287   0.047977
# 287      0.141693   0.071815
# 312     59.927565  58.961903
# 313     36.622140  35.236917
# ...           ...        ...
# 250424   2.261161   1.753050
# 250425   2.762145   2.429912
# 250426   6.532516   5.266244
# 250427   4.509886   3.756234
# 250428   5.376926   4.520883
#
# [1260 rows x 10 columns]

# %%
df[df["cause"].str.contains("HIV")] # строки содержат упоминание HIV (ВИЧ)
# Out:
#        measure                          location     sex       age  \
# 18      Deaths                   Solomon Islands    Male  All Ages
# 19      Deaths                   Solomon Islands  Female  All Ages
# 20      Deaths                   Solomon Islands    Both  All Ages
# 138     Deaths                         Indonesia    Male  All Ages
# 139     Deaths                         Indonesia  Female  All Ages
# ...        ...                               ...     ...       ...
# 256924  Deaths                            Tuvalu  Female  All Ages
# 256925  Deaths                            Tuvalu    Both  All Ages
# 256986  Deaths  Democratic Republic of the Congo    Male  All Ages
# 256987  Deaths  Democratic Republic of the Congo  Female  All Ages
# 256988  Deaths  Democratic Republic of the Congo    Both  All Ages
#
#                                                cause metric  year         val  \
# 18      HIV/AIDS and sexually transmitted infections   Rate  2000   21.364097
# 19      HIV/AIDS and sexually transmitted infections   Rate  2000   20.605195
# 20      HIV/AIDS and sexually transmitted infections   Rate  2000   20.997271
# 138     HIV/AIDS and sexually transmitted infections   Rate  2000    2.581957
# 139     HIV/AIDS and sexually transmitted infections   Rate  2000    1.877628
# ...                                              ...    ...   ...         ...
# 256924  HIV/AIDS and sexually transmitted infections   Rate  2014    6.180238
# 256925  HIV/AIDS and sexually transmitted infections   Rate  2014    7.767307
# 256986  HIV/AIDS and sexually transmitted infections   Rate  2004   69.621952
# 256987  HIV/AIDS and sexually transmitted infections   Rate  2004  119.327766
# 256988  HIV/AIDS and sexually transmitted infections   Rate  2004   94.583595
#
#              upper      lower
# 18       45.320288   7.606704
# 19       43.047910   7.344753
# 20       44.039874   7.615446
# 138       4.727558   1.341722
# 139       3.665094   0.916937
# ...            ...        ...
# 256924   22.473695   1.555340
# 256925   27.490140   2.205626
# 256986   94.502440  49.970749
# 256987  153.633755  90.012653
# 256988  122.411973  70.771831
#
# [12240 rows x 10 columns]

# %%
df[df["cause"].str.contains("HIV") == False] # строки НЕ содержат упоминание ВИЧ
# Out:
#        measure location     sex       age  \
# 0       Deaths    Samoa    Male  All Ages
# 1       Deaths    Samoa  Female  All Ages
# 2       Deaths    Samoa    Both  All Ages
# 3       Deaths    Samoa    Male  All Ages
# 4       Deaths    Samoa  Female  All Ages
# ...        ...      ...     ...       ...
# 257035  Deaths  Comoros  Female  All Ages
# 257036  Deaths  Comoros    Both  All Ages
# 257037  Deaths  Comoros    Male  All Ages
# 257038  Deaths  Comoros  Female  All Ages
# 257039  Deaths  Comoros    Both  All Ages
#
#                                           cause metric  year        val  \
# 0                  Chronic respiratory diseases   Rate  2000  64.470214
# 1                  Chronic respiratory diseases   Rate  2000  55.234399
# 2                  Chronic respiratory diseases   Rate  2000  60.039961
# 3                Skin and subcutaneous diseases   Rate  2000   2.246741
# 4                Skin and subcutaneous diseases   Rate  2000   1.368385
# ...                                         ...    ...   ...        ...
# 257035  Neglected tropical diseases and malaria   Rate  2004  53.727176
# 257036  Neglected tropical diseases and malaria   Rate  2004  55.473969
# 257037             Chronic respiratory diseases   Rate  2004  26.083547
# 257038             Chronic respiratory diseases   Rate  2004  19.658170
# 257039             Chronic respiratory diseases   Rate  2004  22.849508
#
#             upper      lower
# 0       81.808307  53.476793
# 1       77.883497  39.978647
# 2       76.013089  49.941986
# 3        3.467454   1.438979
# 4        1.945448   0.866099
# ...           ...        ...
# 257035  92.205694  24.130322
# 257036  96.573472  24.780106
# 257037  32.912324  18.654426
# 257038  25.456633  14.278054
# 257039  27.877194  17.872866
#
# [244800 rows x 10 columns]

# %%
df[~df["cause"].str.contains("HIV")] # строки НЕ содержат упоминание ВИЧ
# Out:
#        measure location     sex       age  \
# 0       Deaths    Samoa    Male  All Ages
# 1       Deaths    Samoa  Female  All Ages
# 2       Deaths    Samoa    Both  All Ages
# 3       Deaths    Samoa    Male  All Ages
# 4       Deaths    Samoa  Female  All Ages
# ...        ...      ...     ...       ...
# 257035  Deaths  Comoros  Female  All Ages
# 257036  Deaths  Comoros    Both  All Ages
# 257037  Deaths  Comoros    Male  All Ages
# 257038  Deaths  Comoros  Female  All Ages
# 257039  Deaths  Comoros    Both  All Ages
#
#                                           cause metric  year        val  \
# 0                  Chronic respiratory diseases   Rate  2000  64.470214
# 1                  Chronic respiratory diseases   Rate  2000  55.234399
# 2                  Chronic respiratory diseases   Rate  2000  60.039961
# 3                Skin and subcutaneous diseases   Rate  2000   2.246741
# 4                Skin and subcutaneous diseases   Rate  2000   1.368385
# ...                                         ...    ...   ...        ...
# 257035  Neglected tropical diseases and malaria   Rate  2004  53.727176
# 257036  Neglected tropical diseases and malaria   Rate  2004  55.473969
# 257037             Chronic respiratory diseases   Rate  2004  26.083547
# 257038             Chronic respiratory diseases   Rate  2004  19.658170
# 257039             Chronic respiratory diseases   Rate  2004  22.849508
#
#             upper      lower
# 0       81.808307  53.476793
# 1       77.883497  39.978647
# 2       76.013089  49.941986
# 3        3.467454   1.438979
# 4        1.945448   0.866099
# ...           ...        ...
# 257035  92.205694  24.130322
# 257036  96.573472  24.780106
# 257037  32.912324  18.654426
# 257038  25.456633  14.278054
# 257039  27.877194  17.872866
#
# [244800 rows x 10 columns]

# %%
df.drop("measure", axis=1, inplace = True) # удаляем столбец measure

# %%
df.drop(["metric","age","upper","lower"], axis=1, inplace = True) # удаляем столбцы metric, age, upper, lower
df
# Out:
#        location     sex                                    cause  year  \
# 0         Samoa    Male             Chronic respiratory diseases  2000
# 1         Samoa  Female             Chronic respiratory diseases  2000
# 2         Samoa    Both             Chronic respiratory diseases  2000
# 3         Samoa    Male           Skin and subcutaneous diseases  2000
# 4         Samoa  Female           Skin and subcutaneous diseases  2000
# ...         ...     ...                                      ...   ...
# 257035  Comoros  Female  Neglected tropical diseases and malaria  2004
# 257036  Comoros    Both  Neglected tropical diseases and malaria  2004
# 257037  Comoros    Male             Chronic respiratory diseases  2004
# 257038  Comoros  Female             Chronic respiratory diseases  2004
# 257039  Comoros    Both             Chronic respiratory diseases  2004
#
#               val
# 0       64.470214
# 1       55.234399
# 2       60.039961
# 3        2.246741
# 4        1.368385
# ...           ...
# 257035  53.727176
# 257036  55.473969
# 257037  26.083547
# 257038  19.658170
# 257039  22.849508
#
# [257040 rows x 5 columns]

# %%
df["val_round"] = df["val"].round(decimals = 1) 
# создаем новый столбец, в котором будут округленные значения из столбца val
df.head()
# Out:
#   location     sex                           cause  year        val  val_round
# 0    Samoa    Male    Chronic respiratory diseases  2000  64.470214       64.5
# 1    Samoa  Female    Chronic respiratory diseases  2000  55.234399       55.2
# 2    Samoa    Both    Chronic respiratory diseases  2000  60.039961       60.0
# 3    Samoa    Male  Skin and subcutaneous diseases  2000   2.246741        2.2
# 4    Samoa  Female  Skin and subcutaneous diseases  2000   1.368385        1.4

# %%
df.rename(columns = {"val": "value"}, inplace = True) # меняем названием столбца
df
# Out:
#        location     sex                                    cause  year  \
# 0         Samoa    Male             Chronic respiratory diseases  2000
# 1         Samoa  Female             Chronic respiratory diseases  2000
# 2         Samoa    Both             Chronic respiratory diseases  2000
# 3         Samoa    Male           Skin and subcutaneous diseases  2000
# 4         Samoa  Female           Skin and subcutaneous diseases  2000
# ...         ...     ...                                      ...   ...
# 257035  Comoros  Female  Neglected tropical diseases and malaria  2004
# 257036  Comoros    Both  Neglected tropical diseases and malaria  2004
# 257037  Comoros    Male             Chronic respiratory diseases  2004
# 257038  Comoros  Female             Chronic respiratory diseases  2004
# 257039  Comoros    Both             Chronic respiratory diseases  2004
#
#             value  val_round
# 0       64.470214       64.5
# 1       55.234399       55.2
# 2       60.039961       60.0
# 3        2.246741        2.2
# 4        1.368385        1.4
# ...           ...        ...
# 257035  53.727176       53.7
# 257036  55.473969       55.5
# 257037  26.083547       26.1
# 257038  19.658170       19.7
# 257039  22.849508       22.8
#
# [257040 rows x 6 columns]

# %%
df.to_csv("deaths_2000-2019.csv") # сохранение датафрейма в csv на компьютер

# %%
df.loc[:10].to_csv("deaths_10.csv")
