# %%
from natasha import (
    Segmenter,
    MorphVocab,
    
    NewsEmbedding,
    NewsMorphTagger,
    NewsSyntaxParser,
    NewsNERTagger,
    
    PER,
    LOC,
    NamesExtractor,
    DatesExtractor,
    MoneyExtractor,
    AddrExtractor,

    Doc
)

segmenter = Segmenter()
morph_vocab = MorphVocab()

emb = NewsEmbedding()
morph_tagger = NewsMorphTagger(emb)
syntax_parser = NewsSyntaxParser(emb)
ner_tagger = NewsNERTagger(emb)

names_extractor = NamesExtractor(morph_vocab)
dates_extractor = DatesExtractor(morph_vocab)
money_extractor = MoneyExtractor(morph_vocab)
addr_extractor = AddrExtractor(morph_vocab)

# %%
file = open('/Users/alesyamarohovskaya/Desktop/приговор.txt')
text = file.read()

# %%
text
# Out:
# 'ПРИГОВОР\nИМЕНЕМ  РОССИЙСКОЙ ФЕДЕРАЦИИ\n01 декабря 2016 года                                                                     Москва\nПреображенский районный суд Москвы в составе судьи Духновской З.А., при секретаре Горшковой А.А., с участием государственных обвинителей Давыдовой Д.Е., Дудукова М.Ю., Чубенко А.А., подсудимого ************а А.А., его защитников – адвокатов Попова А.В.,  Колокольниковой Е.В., рассмотрев в открытом судебном заседании уголовное дело по обвинению:\n************ ****** **************, ** ** **** года рождения, уроженца г. Москвы, гражданина РФ, зарегистрированного по адресу: *****************, со средне-специальным образованием, холостого, не работающего, не судимого,  в совершении преступления, предусмотренного ч. 3 ст. 30, п.«г» ч. 4 ст. 228-1 УК РФ, \nУСТАНОВИЛ:\n************ ****** ******** совершил покушение на незаконный сбыт наркотических средств, то есть умышленные действия, непосредственно направленные на незаконный сбыт наркотических средств, совершенные группой лиц по предварительному сговору, в крупном размере, при этом преступление не было доведено до конца по не зависящим от него обстоятельствам, а именно:\nТак ************ А.А., с целью быстрого и незаконного материального обогащения, из корыстных побуждений, имея преступный умысел, направленный на незаконный сбыт наркотических средств группой лиц по предварительному сговору, в крупном размере, осознавая общественную опасность последствий своих действий и желая их наступления, в нарушение ст. ст. 5, 8, 14, 20 и 24 Федерального Закона РФ от 8 января 1998 года № 3-ФЗ «О наркотических средствах и психотропных веществах», в неустановленное время и месте, в период до 17 часов 59 минут 16 сентября 2015 года, вступил в предварительный преступный сговор с неустановленными соучастниками, с целью незаконного приобретения и последующего умышленного и незаконного сбыта наркотических средств, в крупном размере, распределили между собой преступные роли каждого и разработали преступный план. \nВо исполнение своего совместного преступного плана, согласно распределению ролей, один из его неустановленных соучастников, в неустановленном время и  месте, в период до 17 часов 59 минут 16 сентября 2015 года, при неустановленных обстоятельствах, в нарушение Федерального закона РФ от 8 января 1998 года № 3-ФЗ «О наркотических средствах и психотропных веществах» незаконно приобрел у неустановленного  лица наркотическое средство – героин, в крупном размере, расфасованное в сто пятьдесят один сверток из полимерного материала общей массой 293,25 г., упакованные в сверток из полимерного материала с веществом, после чего, второй неустановленный соучастник ************а А.А., продолжая реализовывать совместный с последним преступный умысел, поместил указанный сверток с наркотическим средством в тайник, оборудованный возле одиннадцатого дерева от начала зеленого забора на парковке, возле ресторана «Чайхона» по адресу: г.Москва, ул.Первомайская, д. 106а, о месте нахождения которого сообщил ************у А.А. в ходе телефонного разговора первый неустановленный соучастник.\nПродолжая реализовывать совместный с соучастниками преступный умысел, в совместных с соучастниками интересах, ************ А.А. 16 сентября 2015 года, в 17 часов 59 минут прибыл по вышеуказанному адресу, где забрал из вышеуказанного тайника сверток со ста пятьюдесятью одним свертком из полимерного материала, с находящимся внутри каждого свертка наркотическим средством - героин, общей массой 293,25 г., о чем сообщил в ходе телефонного разговора своему первому неустановленному соучастнику, после чего ************ А.А. убрал вышеуказанный сверток с наркотическим средством – героин, в левый карман джинсовых брюк одетых на нём, которое хранил при себе, и данное наркотическое средство по указанию своего первого неустановленного соучастника, с целью дальнейшего сбыта указанного наркотического средства неустановленным лицам через «закладку» должен был направиться по адресу, где совместно и согласованно,  ...

# %%
doc = Doc(text)
doc.segment(segmenter) 
doc.tag_morph(morph_tagger)
doc.parse_syntax(syntax_parser)
doc.tag_ner(ner_tagger)

# %%
doc.segment(segmenter)
display(doc.tokens[:5])
# Out:
# [DocToken(stop=8, text='ПРИГОВОР'),
#  DocToken(start=9, stop=15, text='ИМЕНЕМ'),
#  DocToken(start=17, stop=27, text='РОССИЙСКОЙ'),
#  DocToken(start=28, stop=37, text='ФЕДЕРАЦИИ'),
#  DocToken(start=38, stop=40, text='01')]

# %%
display(doc.sents[:5])
# Out:
# [DocSent(stop=1999, text='ПРИГОВОР\nИМЕНЕМ  РОССИЙСКОЙ ФЕДЕРАЦИИ\n01 декабр..., tokens=[...]),
#  DocSent(start=2001, stop=3080, text='Во исполнение своего совместного преступного план..., tokens=[...]),
#  DocSent(start=3081, stop=6135, text='Продолжая реализовывать совместный с соучастникам..., tokens=[...]),
#  DocSent(start=6137, stop=7085, text='Таким образом, ************ А.А. и его неустановл..., tokens=[...]),
#  DocSent(start=7087, stop=7939, text='Суд, проведя судебное следствие, выслушав судебны..., tokens=[...])]

# %%
doc.tag_morph(morph_tagger)
display(doc.tokens[:5])
# Out:
# [DocToken(stop=8, text='ПРИГОВОР', pos='NOUN', feats=<Inan,Nom,Masc,Sing>),
#  DocToken(start=9, stop=15, text='ИМЕНЕМ', pos='PROPN', feats=<Anim,Gen,Masc,Sing>),
#  DocToken(start=17, stop=27, text='РОССИЙСКОЙ', pos='ADJ', feats=<Gen,Pos,Fem,Sing>),
#  DocToken(start=28, stop=37, text='ФЕДЕРАЦИИ', pos='PROPN', feats=<Inan,Gen,Fem,Sing>),
#  DocToken(start=38, stop=40, text='01', pos='ADJ')]

# %%
for span in doc.spans:
    span.normalize(morph_vocab)

{_.text: _.normal for _ in doc.spans if _.text != _.normal}
# Out:
# {'Москвы': 'Москва',
#  'Давыдовой Д.Е.': 'Давыдова Д.Е.',
#  'Попова А.В.': 'Попов А.В.',
#  'Службы по': 'Служба по',
#  'России': 'Россия',
#  'Москве': 'Москва',
#  'Службы': 'Служба',
#  'Российской Федерации': 'Российская Федерация',
#  'Правительства': 'Правительство',
#  'А.А.\nДопрошенный': 'А.А. Допрошенный',
#  'Биткова А.Ю.': 'Битков А.Ю.',
#  'Русинова А.А.': 'Русинов А.А.',
#  'Кормилицыну Д.А.': 'Кормилицын Д.А.',
#  'Русиновым А.А.': 'Русинов А.А.',
#  'Русинов А.А.': 'Русины А.А.',
#  'Андрея Александровича': 'Андрей Александрович'}

# %%
for token in doc.tokens:
    token.lemmatize(morph_vocab)
    
{_.text: _.lemma for _ in doc.tokens}
# Out:
# {'ПРИГОВОР': 'приговор',
#  'ИМЕНЕМ': 'имя',
#  'РОССИЙСКОЙ': 'российский',
#  'ФЕДЕРАЦИИ': 'федерация',
#  '01': '01',
#  'декабря': 'декабрь',
#  '2016': '2016',
#  'года': 'год',
#  'Москва': 'москва',
#  'Преображенский': 'преображенский',
#  'районный': 'районный',
#  'суд': 'суд',
#  'Москвы': 'москва',
#  'в': 'в',
#  'составе': 'состав',
#  'судьи': 'судья',
#  'Духновской': 'духновский',
#  'З': 'з',
#  '.': '.',
#  'А': 'а',
#  ',': ',',
#  'при': 'при',
#  'секретаре': 'секретарь',
#  'Горшковой': 'горшков',
#  'с': 'с',
#  'участием': 'участие',
#  'государственных': 'государственный',
#  'обвинителей': 'обвинитель',
#  'Давыдовой': 'давыдов',
#  'Д': 'д',
#  'Е': 'е',
#  'Дудукова': 'дудукова',
#  'М': 'м',
#  'Ю': 'ю',
#  'Чубенко': 'чубенко',
#  'подсудимого': 'подсудимый',
#  '************': '************',
#  'а': 'а',
#  'его': 'он',
#  'защитников': 'защитник',
#  '–': '–',
#  'адвокатов': 'адвокат',
#  'Попова': 'попов',
#  'В': 'в',
#  'Колокольниковой': 'колокольников',
#  'рассмотрев': 'рассмотреть',
#  'открытом': 'открыть',
#  'судебном': 'судебный',
#  'заседании': 'заседание',
#  'уголовное': 'уголовный',
#  'дело': 'дело',
#  'по': 'по',
#  'обвинению': 'обвинение',
#  ':': ':',
#  '******': '******',
#  '**************': '**************',
#  '**': '**',
#  '****': '****',
#  'рождения': 'рождение',
#  'уроженца': 'уроженец',
#  'г': 'г',
#  'гражданина': 'гражданин',
#  'РФ': 'рф',
#  'зарегистрированного': 'зарегистрировать',
#  'адресу': 'адрес',
#  '*****************': '*****************',
#  'со': 'с',
#  'средне-специальным': 'средне-специальный',
#  'образованием': 'образование',
#  'холостого': 'холостой',
#  'не': 'не',
#  'работающего': 'работать',
#  'судимого': 'судить',
#  'совершении': 'совершение',
#  'преступления': 'преступление',
#  'предусмотренного': 'предусмотреть',
#  'ч': 'ч',
#  '3': '3',
#  'ст': 'ст',
#  '30': '30',
#  'п': 'п',
#  '«': '«',
#  '»': '»',
#  '4': '4',
#  '228-1': '228-1',
#  'УК': 'ук',
#  'УСТАНОВИЛ': 'установить',
#  '********': '********',
#  'совершил': 'совершить',
#  'покушение': 'покушение',
#  'на': 'на',
#  'незаконный': 'незаконный',
#  'сбыт': 'сбыт',
#  'наркотических': 'наркотический',
#  'средств': 'средство',
#  'то': 'тот',
#  'есть': 'быть',
#  'умышленные': 'умышленный',
#  'действия': 'действие',
#  'непосредственно': 'непосредственно',
#  'направленные': 'направить',
#  'совершенные': 'совершить',
#  'группой': 'группа',
#  'лиц': 'лицо',
#  'предварительному': 'предварительный',
#  'сговору': 'сговор',
#  'крупном': 'крупный',
#  'размере': 'размер',
#  'этом': 'это',
#  'преступление': 'преступление',
#  'было': 'быть',
#  'доведено': 'довести',
#  'до': 'до',
#  'конца': 'конец',
#  'зависящим': 'зависеть',
#  'от': 'от',
#  'него': 'он',
#  'обстоятельствам': 'обстоятельство',
#  'именно': 'именно',
#  'Так': 'так',
#  'целью': 'цель',
#  'быстрого': 'быстрый',
#  'и': 'и',
#  'незаконного': 'незаконный',
#  'материального': 'материальный',
#  'обогащения': 'обогащение',
#  'из': 'из',
#  'корыстных': 'корыстный',
#  'побуждений': 'побуждение',
#  'имея': 'иметь',
#  'преступный': 'преступный',
#  'умысел': 'умысел',
#  'направленный': 'направить',
#  'осознавая': 'осознавать',
#  'общественную': 'общественный',
#  'опасность': 'опасность',
#  'последствий': 'последствие',
#  'своих': 'свой',
#  'действий': 'действие',
#  'желая': 'желать',
#  'их': 'они',
#  'наступления': 'наступление',
#  'нарушение': 'нарушение',
#  '5,': '5,',
#  '8,': '8,',
#  '14,': '14,',
#  '20': '20',
#  '24': '24',
#  'Федерального': 'федеральный',
#  'Закона': 'закон',
#  '8': '8',
#  'января': 'январь',
#  '1998': '1998',
#  '№': '№',
#  '3-ФЗ': '3-фз',
#  'О': 'о',
#  'средствах': 'средство',
#  'психотропных': 'психотропный',
#  'веществах': 'вещество',
#  'неустановленное': 'неустановленный',
#  'время': 'время',
#  'месте': 'место',
#  'период': 'период',
#  '17': '17',
#  'часов': 'час',
#  '59': '59',
#  'минут': 'минута',
#  '16': '16',
#  'сентября': 'сентябрь',
#  '2015': '2015',
#  'вступил': 'вступить',
#  'предварительный': 'предварительный',
#  'сговор': 'сговор',
#  'неустановленными': 'неустановленный',
#  'соучастниками': 'соучастник',
#  'приобретения': 'приобретение',
#  'последующего': 'последующий',
#  'умышленного': 'умышленный',
#  'сбыта': 'сбыт',
#  'распределили': 'распределить',
#  'между': 'между',
#  'собой': 'себя',
#  'преступные': 'преступный',
#  'роли': 'роль',
#  'каждого': 'каждый',
#  'разработали': 'разработать',
#  'план': 'план',
#  'Во': 'в',
#  'исполнение': 'исполнение',
#  'своего': 'свой',
#  'совместного': 'совместный',
#  'преступного': 'преступный',
#  'плана': 'план',
#  'согласно': 'согласно',
#  'распределению': 'распределение',
#  'ролей': 'роль',
#  'один': 'один',
#  'неустановленных': 'неустановленный',
#  'соучастников': 'соучастник',
#  'неустановленном': 'неустановленный',
#  'обстоятельствах': 'обстоятельство',
#  'закона': 'закон',
#  'незаконно': 'незаконно',
#  'приобрел': 'приобрести',
#  'у': 'у',
#  'неустановленного': 'неустановленный',
#  'лица': 'лицо',
#  'наркотическое': 'наркотический',
#  'средство': 'средство',
#  'героин': 'героин',
#  'расфасованное': 'расфасовать',
#  'сто': 'сто',
#  'пятьдесят': 'пятьдесят',
#  'сверток': 'сверток',
#  'полимерного': 'полимерный',
#  'материала': 'материал',
#  'общей': 'общий',
#  'массой': 'масса',
#  '293,25': '293,25',
#  'упакованные': 'упаковать',
#  'веществом': 'вещество',
#  'после': 'после',
#  'чего': 'что',
#  'второй': 'второй',
#  'неустановленный': 'неустановленный',
#  'соучастник': 'соучастник',
#  'продолжая': 'продолжать',
#  'реализовывать': 'реализовывать',
#  'совместный': 'совместный',
#  'последним': 'последний',
#  'поместил': 'поместить',
#  'указанный': 'указать',
#  'наркотическим': 'наркотический',
#  'средством': 'средство',
#  'тайник': 'тайник',
#  'оборудованный': 'оборудовать',
#  'возле': 'возле',
#  'одиннадцатого': 'одиннадцатый',
#  'дерева': 'дерево',
#  'начала': 'начало',
#  'зеленого': 'зеленый',
#  'забора': 'забор',
#  'парковке': 'парковка',
#  'ресторана': 'ресторан',
#  'Чайхона': 'чайхон',
#  'ул': 'ул',
#  'Первомайская': 'первомайский',
#  'д': 'далее',
#  '106': '106',
#  'о': 'о',
#  'нахождения': 'нахождение',
#  'которого': 'который',
#  'сообщил': 'сообщить',
#  'ходе': 'ход',
#  'телефонного': 'телефонный',
#  'разговора': 'разговор',
#  'первый': 'первый',
#  'Продолжая': 'продолжать',
#  'совместных': 'совместный',
#  'интересах': 'интерес',
#  'прибыл': 'прибыть',
#  'вышеуказанному': 'вышеуказанный',
#  'где': 'где',
#  'забрал': 'забрать',
#  'вышеуказанного': 'вышеуказанный',
#  'тайника': 'тайник',
#  'ста': 'сто',
#  'пятьюдесятью': 'пятьюдесятью',
#  'одним': 'один',
#  'свертком': 'сверток',
#  'находящимся': 'находиться',
#  'внутри': 'внутри',
#  'свертка': 'сверток',
#  '-': '-',
#  'чем': 'что',
#  'своему': 'свой',
#  'первому': 'первый',
#  'неустановленному': 'неустановленный',
#  'соучастнику': 'соучастник',
#  'убрал': 'убрать',
#  'вышеуказанный': 'вышеуказанный',
#  'левый': 'левый',
#  'карман': 'карман',
#  'джинсовых': 'джинсовый',
#  'брюк': 'брюки',
#  'одетых': 'одеть',
#  'нём': 'нем',
#  'которое': 'который',
#  'хранил': 'хранить',
#  'себе': 'себя',
#  'данное': 'данный',
#  'указанию': 'указание',
#  'первого': 'первый',
#  'соучастника': 'соучастник',
#  'дальнейшего': 'дальнейший',
#  'указанного': 'указать',
#  'наркотического': 'наркотический',
#  'средства': 'средство',
#  'неустановленным': 'неустановленный',
#  'лицам': 'лицо',
#  'через': 'через',
#  'закладку': 'закладка',
#  'должен': 'должный',
#  'был': 'быть',
#  'направиться': 'направиться',
#  'совместно': 'совместно',
#  'согласованно': 'согласованно',
#  'второго': 'второй',
#  'планировал': 'планировать',
#  'поместить': 'поместить',
#  'наркотические': 'наркотический',
#  'закладки': 'закладка',
#  'местах': 'место',
#  'однако': 'однако',
#  'неустановленные': 'неустановленный',
#  'соучастники': 'соучастник',
#  'смогли': 'смочь',
#  'осуществить': 'осуществить',
#  'свой': 'свой',
#  'них': 'они',
#  'так': 'так',
#  'как': 'как',
#  '18': '18',
#  '10': '10',
#  'задержан': 'задержать',
#  'сотрудниками': 'сотрудник',
#  '2': '2',
#  'отдела': 'отдел',
#  'Службы': 'служба',
#  'ВАО': 'вао',
#  'ФСКН': 'фскн',
#  'России': 'россия',
#  'Москве': 'москва',
#  'проведенного': 'провести',
#  'оперативно': 'оперативно',
#  'розыскного': 'розыскной',
#  'мероприятия': 'мероприятие',
#  'Наблюдение': 'наблюдение',
#  'Далее': 'далее',
#  'времени': 'время',
#  '19': '19',
#  '25': '25',
#  'помещении': 'помещение',
#  'расположенном': 'расположить',
#  'Буженинова': 'буженинов',
#  '12': '12',
#  'проведения': 'проведение',
#  'личного': 'личный',
#  'досмотра': 'досмотр',
#  'левого': 'левый',
#  'кармана': 'карман',
#  'штанов': 'штаны',
#  'е': 'е',
#  'обнаружен': 'обнаружить',
#  'изъят': 'изъять',
#  'находился': 'находиться',
#  '151': '151',
#  '(': '(',
#  ')': ')',
#  'расфасованный': 'расфасовать',
#  'полимерный': 'полимерный',
#  'материал': 'материал',
#  'виде': 'вид',
#  'порошка': 'порошок',
#  'комков': 'комок',
#  'заключению': 'заключение',
#  'эксперта': 'эксперт',
#  'Э-1/2317-15': 'э-1/2317-15',
#  'октября': 'октябрь',
#  'является': 'являться',
#  'Постановлению': 'постановление',
#  'Правительства': 'правительство',
#  'Российской': 'российский',
#  'Федерации': 'федерация',
#  'июня': 'июнь',
#  '681': '681',
#  'Об': 'о',
#  'утверждении': 'утверждение',
#  'перечня': 'перечень',
#  'веществ': 'вещество',
#  'прекурсоров': 'прекурсор',
#  'подлежащих': 'подлежать',
#  'контролю': 'контроль',
#  'редакции': 'редакция',
#  'постановления': 'постановление',
#  '1': '1',
#  'апреля': 'апрель',
#  '256': '256',
#  'входят': 'входить',
#  'список': 'список',
#  'оборот': 'оборот',
#  'которых': 'который',
#  'запрещен': 'запретить',
#  'пятидесяти': 'пятьдесят',
#  'одного': 'один',
#  'что': 'что',
#  '2012': '2012',
#  '1002': '1002',
#  'значительного': 'значительный',
#  'крупного': 'крупный',
#  'особо': 'особо',
#  'размеров': 'размер',
#  'также': 'также',
#  'для': 'для',
#  'растений': 'растение',
#  'содержащих': 'содержать',
#  'или': 'или',
#  'психотропные': 'психотропный',
#  'вещества': 'вещество',
#  'либо': 'либо',
#  'частей': 'часть',
#  'целей': 'цель',
#  'статей': 'стать',
#  '228,': '228,',
#  '228': '228',
#  '¹': '¹',
#  '229': '229',
#  'крупным': 'крупный',
#  'размером': 'размер',
#  'Таким': 'такой',
#  'образом': 'образ',
#  'действуя': 'действовать',
#  'довели': 'довести',
#  'вышеуказанное': 'вышеуказанный',
#  'изъято': 'изъять',
#  'Допрошенный': 'допросить',
#  'подсудимый': 'подсудимый',
#  'вину': 'вина',
#  'признал': 'признать',
#  'частично': 'частично',
#  'подтвердил': 'подтвердить',
#  'фактические': 'фактический',
#  'обстоятельства': 'обстоятельство',
#  'изложенные': 'изложить',
#  'выше': 'выше',
#  'показал': 'показать',
#  'собственного': 'собственный',
#  'употребления': 'употребление',
#  'общим': 'общий',
#  'весом': 'вес',
#  'обнаружено': 'обнаружить',
#  'изложенных': 'изложить',
#  'отрицал': 'отрицать',
#  'Суд': 'суд',
#  'проведя': 'провести',
#  'судебное': 'судебный',
#  'следствие': 'следствие',
#  'выслушав': 'выслушать',
#  'судебные': 'судебный',
#  'прения': 'прение',
#  'последнее': 'последний',
#  'слово': 'слово',
#  'считает': 'считать',
#  'вина': 'вино',
#  'инкриминируемом': 'инкриминировать',
#  'преступлении': 'преступление',
#  'доказана': 'доказать',
#  'следующими': 'следующий',
#  'исследованными': 'исследовать',
#  'доказательствами': 'доказательство',
#  'показаниями': 'показание',
#  'предварительном': 'предварительный',
#  'следствии': 'следствие',
#  'которым': 'который',
#  'извлек': 'извлечь',
#  'героином': 'героин',
#  ';': ';',
#  'свидетелей': 'свидетель',
#  'Биткова': 'битков',
#  'Орел': 'орел',
#  'И': 'и',
#  'понятых': 'понятой',
#  'основном': 'основный',
#  'аналогичными': 'аналогичный',
#  'личном': 'личный',
#  'досмотре': 'досмотр',
#  'изъяты': 'изъять',
#  'джинс': 'джинс',
#  'свертками': 'свертка',
#  'полиэтилена': 'полиэтилен',
#  'мобильные': 'мобильный',
#  'телефоны': 'телефон',
#  'Самсунг': 'самсунг',
#  'Сони': 'соня',
#  'Эриксон': 'эриксон',
#  'сим-карты': 'сим-карта',
#  'шприц': 'шприц',
#  'два': 'два',
#  'пузырька': 'пузырек',
#  'пояснил': 'пояснить',
#  'свертках': 'сверток',
#  'Процедура': 'процедура',
#  'снималась': 'сниматься',
#  'видеокамеру': 'видеокамера',
#  'свидетеля': 'свидетель',
#  'Русинова': 'русинов',
#  'вечернее': 'вечерний',
#  'он': 'он',
#  'Русинов': 'русин',
#  'предложению': 'предложение',
#  'последнего': 'последний',
#  'подошли': 'подойти',
#  'к': 'к',
#  'дому': 'дом',
#  'Первомайской': 'первомайский',
#  'ресторану': 'ресторан',
#  'Чайхана': 'чайхана',
#  'подняв': 'поднять',
#  'что-то': 'что-то',
#  'около': 'около',
#  'положил': 'положить',
#  'Около': 'около',
#  'дома': 'дом',
#  'были': 'быть',
#  'задержаны': 'задержать',
#  'полицией': 'полиция',
#  'доставлены': 'доставить',
#  'проведен': 'провести',
#  'личный': 'личный',
#  'досмотр': 'досмотр',
#  'получены': 'получить',
#  'срезы': 'срез',
#  'ногтевых': 'ногтевой',
#  'пластин': 'пластина',
#  'смывы': 'смыв',
#  'Прасолова': 'прасоловый',
#  'Кормилицына': 'кормилицын',
#  'Лукашенко': 'лукашенко',
#  'полицейских': 'полицейский',
#  'рамках': 'рамка',
#  'ОРМ': 'орм',
#  'свертке': 'сверток',
#  'принадлежат': 'принадлежать',
#  'ему': 'он',
#  'рюкзак': 'рюкзак',
#  'Русинову': 'русинов',
#  'выдал': 'выдать',
#  'Кормилицыну': 'кормилицын',
#  'При': 'при',
#  'осмотре': 'осмотр',
#  'видеофайл': 'видеофайл',
#  'личным': 'личный',
#  'досмотром': 'досмотр',
#  'протоколом': 'протокол',
#  'очной': 'очный',
#  'ставки': 'ставка',
#  'обвиняемым': 'обвинять',
#  'свидетелем': 'свидетель',
#  'Русиновым': 'русинов',
#  'которой': 'который',
#  'дал': 'дать',
#  'показания': 'показание',
#  'аналогичные': 'аналогичный',
#  'ранее': 'ранее',
#  'данным': 'данные',
#  'изложенным': 'изложить',
#  'л': 'л',
#  '82-86': '82-86',
#  'актом': 'акт',
#  'изъятия': 'изъятие',
#  'присутствии': 'присутствие',
#  'светлого': 'светлый',
#  'цвета': 'цвет',
#  'SONY': 'sony',
#  'ERICSSON': 'ericsson',
#  'IMEI': 'imei',
#  '3559901-570169-9': '3559901-570169-9',
#  'сим-картой': 'сим-карта',
#  'оператора': 'оператор',
#  'сотовой': 'сотовый',
#  'связи': 'связь',
#  'Билайн': 'билайн',
#  'Samsung': 'samsung',
#  '357795/05/044571/1': '357795/05/044571/1',
#  'Мегафон': 'мегафон',
#  '15-20': '15-20',
#  'осмотра': 'осмотр',
#  'копирования': 'копирование',
#  'видео-материалов': 'видео-материал',
#  'выдана': 'выдать',
#  'цифровая': 'цифровой',
#  'видеокамера': 'видеокамера',
#  'Panasonic': 'panasonic',
#  'HC-V': 'hc-v',
#  '11': '11',
#  'ЕЕ': 'она',
#  'камера': 'камера',
#  'осмотрена': 'осмотреть',
#  'обнаруженная': 'обнаружить',
#  'информация': 'информация',
#  'перекопирована': 'перекопировать',
#  'диск': 'диск',
#  'DVD-R': 'dvd-r',
#  'протоколами': 'протокол',
#  'предметов': 'предмет',
#  'осмотрены': 'осмотреть',
#  'конверты': 'конверт',
#  'пакет': 'пакет',
#  'поступившие': 'поступить',
#  'экспертизы': 'экспертиза',
#  'вскрывались': 'вскрываться',
#  'мобильными': 'мобильный',
#  'телефонами': 'телефон',
#  'шприцем': 'шприц',
#  'формата': 'формат',
#  'DVD': 'dvd',
#  'R': 'r',
#  'MFP': 'mfp',
#  '696': '696',
#  'SKO': 'sko',
#  '222264': '222264',
#  'видеозаписью': 'видеозапись',
#  'компакт': 'компакт',
#  'диски': 'диск',
#  'Smart': 'smart',
#  'Track': 'track',
#  'CD-R': 'cd-r',
#  '52': '52',
#  'х': 'х',
#  'записями': 'запись',
#  'ПТП': 'птп',
#  '106-108,114-115,160-168': '106-108,114-115,160-168',
#  'заключением': 'заключение',
#  'химической': 'химический',
#  'судебной': 'судебный',
#  'которому': 'который',
#  'светло-бежевого': 'светло-бежевый',
#  'упаковки': 'упаковка',
#  'изъятые': 'изъять',
#  '293,15': '293,15',
#  'После': 'после',
#  'масса': 'масса',
#  '290,13': '290,13',
#  '97-103': '97-103',
#  'рапортом': 'рапортом',
#  'об': 'о',
#  'обнаружении': 'обнаружение',
#  'признаков': 'признак',
#  'действиях': 'действие',
#  'справкой': 'справка',
#  'исследовании': 'исследование',
#  'И-1/1657': 'и-1/1657',
#  'пакете': 'пакет',
#  'каждом': 'каждый',
#  'На': 'на',
#  'исследование': 'исследование',
#  'отбиралась': 'отбиралась',
#  'представительная': 'представительный',
#  'проба': 'проба',
#  '0,01': '0,01',
#  'десяти': 'десять',
#  'свертков': 'сверток',
#  'Общая': 'общий',
#  'исследованных': 'исследовать',
#  '20,05': '20,05',
#  'Установлено': 'установить',
#  'исследуемых': 'исследовать',
#  'содержится': 'содержаться',
#  '51': '51',
#  'места': 'место',
#  'происшествия': 'происшествие',
#  'осмотрен': 'осмотреть',
#  'участок': 'участок',
#  'местности': 'местность',
#  'ничего': 'ничто',
#  'изымалось': 'изыматься',
#  '205-206': '205-206',
#  'постановлением': 'постановление',
#  'признании': 'признание',
#  'приобщении': 'приобщение',
#  'качестве': 'качество',
#  'вещественных': 'вещественный',
#  'доказательств': 'доказательство',
#  'героина': 'героин',
#  'изъятого': 'изъять',
#  'срезов': 'срез',
#  'смывов': 'смыв',
#  'компакт-дисков': 'компакт-диск',
#  'мобильный': 'мобильный',
#  'телефон': 'телефон',
#  '109-110,': '109-110,',
#  '117-118': '117-118',
#  'Оценивая': 'оценивать',
#  'вышеприведенные': 'вышеприведенный',
#  'доказательства': 'доказательство',
#  'совокупности': 'совокупность',
#  'признавая': 'признавать',
#  'относимыми': 'относить',
#  'допустимыми': 'допустимый',
#  'делу': 'дело',
#  'существенных': 'существенный',
#  'противоречий': 'противоречие',
#  'достаточными': 'достаточный',
#  'приходит': 'приходить',
#  'выводу': 'вывод',
#  'доказанности': 'доказанность',
#  'вины': 'вина',
#  'описанного': 'описать',
#  'приговоре': 'приговор',
#  'этим': 'это',
#  'квалифицирует': 'квалифицировать',
#  'доверяет': 'доверять',
#  'показаниям': 'показание',
#  'части': 'часть',
#  'отрицания': 'отрицание',
#  'умысла': 'умысел',
#  'этой': 'этот',
#  'опровергаются': 'опровергаться',
#  'суда': 'суд',
#  'оснований': 'основание',
#  'доверять': 'доверять',
#  'нет': 'нет',
#  'они': 'они',
#  'последовательны': 'последовательный',
#  'непротиворечивы': 'непротиворечивый',
#  'согласуются': 'согласоваться',
#  'всеми': 'весь',
#  'Кроме': 'кроме',
#  'того': 'тот',
#  'наличии': 'наличие',
#  'мнению': 'мнение',
#  'свидетельствует': 'свидетельствовать',
#  'объем': 'объем',
#  'расфасовка': 'расфасовка',
#  'изъятие': 'изъятие',
#  'произошло': 'произойти',
#  'назначении': 'назначение',
#  'наказания': 'наказание',
#  'учитывает': 'учитывать',
#  'характер': 'характер',
#  'степень': 'степень',
#  'общественной': 'общественный',
#  'опасности': 'опасность',
#  'совершенного': 'совершить',
#  'отнесенного': 'отнести',
#  'законодателем': 'законодатель',
#  'категории': 'категория',
#  'тяжких': 'тяжкий',
#  'данные': 'данные',
#  'личности': 'личность',
#  'учитывая': 'учитывать',
#  'следующее': 'следующий',
#  'Подсудимый': 'подсудимый',
#  'судим': 'судить',
#  'страдает': 'страдать',
#  'заболеваниями': 'заболевание',
#  'мать': 'мать',
#  'пенсионерка': 'пенсионерка',
#  'ветеран': 'ветеран',
#  'труда': 'труд',
#  'признает': 'признавать',
#  'обстоятельств': 'обстоятельство',
#  'смягчающих': 'смягчать',
#  'наказание': 'наказание',
#  'Обстоятельств': 'обстоятельство',
#  'отягчающих': 'отягчать',
#  'судом': 'суд',
#  'установлено': 'установить',
#  'С': 'с',
#  'учетом': 'учет',
#  'конкретных': 'конкретный',
#  'дела': 'дело',
#  'данных': 'данные',
#  'исправление': 'исправление',
#  'возможно': 'возможный',
#  'только': 'только',
#  'условиях': 'условие',
#  'изоляции': 'изоляция',
#  'общества': 'общество',
#  'назначая': 'назначать',
#  'лишения': 'лишение',
#  'свободы': 'свобода',
#  'усматривает': 'усматривать',
#  'применения': 'применение',
#  '15': '15',
#  '6,64,73': '6,64,73',
#  'смягчающие': 'смягчать',
#  'полагает': 'полагать',
#  'нецелесообразным': 'нецелесообразный',
#  'назначение': 'назначение',
#  'дополнительного': 'дополнительный',
#  'штрафа': 'штраф',
#  'Учитывая': 'учитывать',
#  'работает': 'работать',
#  'назначения': 'назначение',
#  'права': 'право',
#  'занимать': 'занимать',
#  'определенные': 'определить',
#  'должности': 'должность',
#  'заниматься': 'заниматься',
#  'определенной': 'определенный',
#  'деятельностью': 'деятельность',
#  'Местом': 'место',
#  'отбывания': 'отбывание',
#  'определяет': 'определять',
#  'исправительную': 'исправительный',
#  'колонию': 'колония',
#  'строгого': 'строгий',
#  'режима': 'режим',
#  'постановлении': 'постановление',
#  'приговора': 'приговор',
#  'необходимым': 'необходимый',
#  'распорядиться': 'распорядиться',
#  'судьбой': 'судьба',
#  'основании': 'основание',
#  'изложенного': 'изложить',
#  'руководствуясь': 'руководствоваться',
#  '296-299,': '296-299,',
#  '307-309': '307-309',
#  'УПК': 'упк',
#  'ПРИГОВОРИЛ': 'приговорить',
#  '******************': '******************',
#  'признать': 'признать',
#  'виновным': 'виновный',
#  'назначить': 'назначить',
#  'сроком': 'срок',
#  'десять': 'десять',
#  'лет': 'год',
#  'отбыванием': 'отбывание',
#  'исправительной': 'исправительный',
#  'колонии': 'колония',
#  'исчислением': 'исчисление',
#  'срока': 'срок',
#  'Засчитать': 'засчитать',
#  'срок': 'срок',
#  'отбытия': 'отбытие',
#  'содержания': 'содержание',
#  'Андрея': 'андрей',
#  'Александровича': 'александрович',
#  'под': 'под',
#  'стражей': 'стража',
#  'Меру': 'мера',
#  'пресечения': 'пресечение',
#  'осужденному': 'осудить',
#  '***************************': '***************************',
#  'вступления': 'вступление',
#  'законную': 'законный',
#  'силу': 'сила',
#  'оставить': 'оставить',
#  'прежней': 'прежний',
#  'содержание': 'содержание',
#  'Вещественное': 'вещественный',
#  'доказательство': 'доказательство',
#  'сим': 'сим',
#  'карту': 'карта',
#  'уничтожить': 'уничтожить',
#  'материалах': 'материал',
#  'уголовного': 'уголовный',
#  'вернуть': 'вернуть',
#  'принадлежности': 'принадлежность',
#  'Приговор': 'приговор',
#  'может': 'мочь',
#  'быть': 'быть',
#  'обжалован': 'обжаловать',
#  'Московский': 'московский',
#  'городской': 'городской',
#  'течение': 'течение',
#  'дней': 'день',
#  'дня': 'день',
#  'провозглашения': 'провозглашение',
#  'осужденным': 'осудить',
#  'тот': 'тот',
#  'же': 'же',
#  'получения': 'получение',
#  'им': 'он',
#  'копии': 'копия',
#  'случае': 'случай',
#  'подачи': 'подача',
#  'апелляционной': 'апелляционный',
#  'жалобы': 'жалоба',
#  'осужденный': 'осудить',
#  'имеет': 'иметь',
#  'право': 'право',
#  'принять': 'принять',
#  'участие': 'участие',
#  'рассмотрении': 'рассмотрение',
#  'инстанции': 'инстанция',
#  'Судья': 'судья',
#  'Духновская': 'духновский'}

# %%
matches = dates_extractor(text)
facts = [i.fact.as_json for i in matches]
facts
# Out:
# [OrderedDict([('year', 2016), ('month', 12), ('day', 1)]),
#  OrderedDict([('year', 1998), ('month', 1), ('day', 8)]),
#  OrderedDict([('year', 2015), ('month', 9), ('day', 16)]),
#  OrderedDict([('year', 2015), ('month', 9), ('day', 16)]),
#  OrderedDict([('year', 1998), ('month', 1), ('day', 8)]),
#  OrderedDict([('year', 2015), ('month', 9), ('day', 16)]),
#  OrderedDict([('year', 2015), ('month', 9), ('day', 16)]),
#  OrderedDict([('year', 2015), ('month', 9), ('day', 16)]),
#  OrderedDict([('year', 2015), ('month', 10), ('day', 16)]),
#  OrderedDict([('year', 1998), ('month', 6), ('day', 30)]),
#  OrderedDict([('year', 2016), ('month', 4), ('day', 1)]),
#  OrderedDict([('year', 2012), ('month', 10), ('day', 1)]),
#  OrderedDict([('year', 2015), ('month', 9), ('day', 16)]),
#  OrderedDict([('year', 2015), ('month', 9), ('day', 16)]),
#  OrderedDict([('year', 2015), ('month', 9), ('day', 16)]),
#  OrderedDict([('year', 2015), ('month', 9), ('day', 16)]),
#  OrderedDict([('year', 2015), ('month', 9), ('day', 16)]),
#  OrderedDict([('year', 2015), ('month', 9), ('day', 16)]),
#  OrderedDict([('year', 2016), ('month', 12), ('day', 1)]),
#  OrderedDict([('year', 2015), ('month', 9), ('day', 16)]),
#  OrderedDict([('year', 2016), ('month', 12), ('day', 1)])]

# %%
for f in facts:
    print(f"{f.get('day')}.{f.get('month')}.{f.get('year')}")
# Out:
# 1.12.2016
# 8.1.1998
# 16.9.2015
# 16.9.2015
# 8.1.1998
# 16.9.2015
# 16.9.2015
# 16.9.2015
# 16.10.2015
# 30.6.1998
# 1.4.2016
# 1.10.2012
# 16.9.2015
# 16.9.2015
# 16.9.2015
# 16.9.2015
# 16.9.2015
# 16.9.2015
# 1.12.2016
# 16.9.2015
# 1.12.2016

# %%
for span in doc.spans:
    if span.type == PER:
        span.extract_fact(names_extractor)

names_dict = {_.normal: _.fact.as_dict for _ in doc.spans if _.fact}
names_dict
# Out:
# {'Духновской З.А.': {'first': 'З', 'last': 'Духновской', 'middle': 'А'},
#  'Горшковой А.А.': {'first': 'А', 'last': 'Горшковой', 'middle': 'А'},
#  'Давыдова Д.Е.': {'first': 'Д', 'last': 'Давыдова', 'middle': 'Е'},
#  'Дудукова М.Ю.': {'first': 'М', 'last': 'Дудукова', 'middle': 'Ю'},
#  'Чубенко А.А.': {'first': 'А', 'last': 'Чубенко', 'middle': 'А'},
#  'А.А.': {'last': 'А'},
#  'Попов А.В.': {'first': 'А', 'last': 'Попов', 'middle': 'В'},
#  'Колокольниковой Е.В.': {'first': 'Е',
#   'last': 'Колокольниковой',
#   'middle': 'В'},
#  'Так ************ А.А.': {'last': 'А'},
#  'А.А. Допрошенный': {'first': 'А', 'last': 'Допрошенный', 'middle': 'А'},
#  'Битков А.Ю.': {'first': 'А', 'last': 'Битков', 'middle': 'Ю'},
#  'Орел И.В.': {'first': 'И', 'last': 'Орел', 'middle': 'В'},
#  'Русинов А.А.': {'first': 'А', 'last': 'Русинов', 'middle': 'А'},
#  'Прасолова Д.А.': {'first': 'Д', 'last': 'Прасолова', 'middle': 'А'},
#  'Кормилицына Д.А.': {'first': 'Д', 'last': 'Кормилицына', 'middle': 'А'},
#  'Лукашенко А.А.': {'first': 'А', 'last': 'Лукашенко', 'middle': 'А'},
#  'Русинову А.А. Лукашенко': {'first': 'А', 'last': 'Русинову', 'middle': 'А'},
#  'Кормилицын Д.А.': {'first': 'Д', 'last': 'Кормилицын', 'middle': 'А'},
#  'Русины А.А.': {'first': 'А', 'last': 'Русины', 'middle': 'А'},
#  'А.А': {'last': 'А'},
#  'Андрей Александрович': {'first': 'Андрей', 'last': 'Александрович'},
#  'Духновская З.А.': {'first': 'З', 'last': 'Духновская', 'middle': 'А'}}

# %%
list(names_dict.keys())
# Out:
# ['Духновской З.А.',
#  'Горшковой А.А.',
#  'Давыдова Д.Е.',
#  'Дудукова М.Ю.',
#  'Чубенко А.А.',
#  'А.А.',
#  'Попов А.В.',
#  'Колокольниковой Е.В.',
#  'Так ************ А.А.',
#  'А.А. Допрошенный',
#  'Битков А.Ю.',
#  'Орел И.В.',
#  'Русинов А.А.',
#  'Прасолова Д.А.',
#  'Кормилицына Д.А.',
#  'Лукашенко А.А.',
#  'Русинову А.А. Лукашенко',
#  'Кормилицын Д.А.',
#  'Русины А.А.',
#  'А.А',
#  'Андрей Александрович',
#  'Духновская З.А.']
