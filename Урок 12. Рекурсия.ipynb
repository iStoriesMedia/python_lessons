# %% [markdown]
# # Рекурсия

# %%
# Прием в программировании, когда функция вызывает саму себя

# %%
def find_even(num_list):
    even = [num for num in num_list if num % 2 == 0]
    return even

# %%
numbers = [1, 2, 3, 4, 5, 6, 7, 8, 10]

# %%
find_even(numbers)
# Out:
# [2, 4, 6, 8, 10]

# %%
def recurs_find_even(num_list,   result = []):
    if not num_list:
        return 
    else:
        first_element = num_list[0]
        if first_element % 2 == 0:
            result.append(first_element)
        recurs_find_even(num_list[1:])
        print(result)
        return result

# %%
recurs_find_even(numbers)
# Out:
# [2, 4, 6, 8, 10]
# [2, 4, 6, 8, 10]
# [2, 4, 6, 8, 10]
# [2, 4, 6, 8, 10]
# [2, 4, 6, 8, 10]
# [2, 4, 6, 8, 10]
# [2, 4, 6, 8, 10]
# [2, 4, 6, 8, 10]
# [2, 4, 6, 8, 10]
# [2, 4, 6, 8, 10]

# %%
data = {
    'url': 'https://clearspending.ru/contract/2772765679021000015/',
    'contracts': {'number': 235678, 'date': '2020-01-31'},
    'sum': {'total': 456000, 'currency': 'RUB'}
}

# %%
date = data.get('contracts')
if date is not None:
    print(date['date'])
# Out:
# 2020-01-31

# %%
def recurs_find_key(key, obj):
    if key in obj:
        return obj[key]
    for k, v in obj.items():
        if type(v) == dict:
            result = recurs_find_key(key, v)
            if result is not None:
                return result

# %%
recurs_find_key('currency', data)
# Out:
# 'RUB'
